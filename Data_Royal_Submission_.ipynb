# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
file_path = '/content/drive/My Drive/Fraud Detection Dataset.csv'
data = pd.read_csv(file_path)

# %%
print(data.shape)
# Out:
# (6000000, 32)

# %%
data.head()
# Out:
#    Transaction ID  User ID  Transaction Amount Transaction Date and Time  \
# 0        51595306     9822              163.08       2023-01-02 07:47:54
# 1        85052974     4698              430.74       2021-09-12 15:15:41
# 2        23954324     8666              415.74       2023-01-12 17:25:58
# 3        44108303     9012              565.89       2021-02-27 11:31:00
# 4        66622683     5185              955.49       2022-09-24 04:06:38
#
#    Merchant ID Payment Method Country Code Transaction Type  \
# 0         4044   ACH Transfer          KOR          Charity
# 1         4576      2Checkout          VNM         Cashback
# 2         4629  Google Wallet          MEX           Reward
# 3         3322          Check          SGP         Purchase
# 4         7609       Worldpay          HKG      Acquisition
#
#                    Device Type      IP Address  ...  \
# 0                   GPS Device   42.23.223.120  ...
# 1               Medical Device   39.52.212.120  ...
# 2  Vehicle Infotainment System  243.180.236.29  ...
# 3                        Kiosk  212.186.227.14  ...
# 4                 Smart Mirror  166.113.10.199  ...
#
#   User's Transaction History Merchant's Reputation Score  \
# 0                         26                        2.71
# 1                         60                        3.95
# 2                         81                        3.81
# 3                         18                        2.67
# 4                         98                        3.19
#
#   User's Device Location  Transaction Currency    Transaction Purpose  \
# 0         United Kingdom                   NOK       Consultation Fee
# 1                 Mexico                   EGP        Cashback Reward
# 2                  Qatar                   MXN            Acquisition
# 3                  Spain                   CLP         Loan Repayment
# 4                 Israel                   RUB  Dividend Reinvestment
#
#    User's Credit Score User's Email Domain Merchant's Business Age  \
# 0                  343           cox.co.uk                       3
# 1                  688           gmail.com                      13
# 2                  371      rocketmail.com                       7
# 3                  687    roadrunner.co.uk                      15
# 4                  605    protonmail.co.uk                      17
#
#   Transaction Authentication Method  Fraudulent Flag
# 0          Bluetooth Authentication                0
# 1                           NFC Tag                1
# 2                             Token                1
# 3                    Time-Based OTP                1
# 4                          Password                1
#
# [5 rows x 32 columns]

# %%
data.columns
# Out:
# Index(['Transaction ID', 'User ID', 'Transaction Amount',
#        'Transaction Date and Time', 'Merchant ID', 'Payment Method',
#        'Country Code', 'Transaction Type', 'Device Type', 'IP Address',
#        'Browser Type', 'Operating System', 'Merchant Category', 'User Age',
#        'User Occupation', 'User Income', 'User Gender', 'User Account Status',
#        'Transaction Status', 'Location Distance', 'Time Taken for Transaction',
#        'Transaction Time of Day', 'User's Transaction History',
#        'Merchant's Reputation Score', 'User's Device Location',
#        'Transaction Currency', 'Transaction Purpose', 'User's Credit Score',
#        'User's Email Domain', 'Merchant's Business Age',
#        'Transaction Authentication Method', 'Fraudulent Flag'],
#       dtype='object')

# %%
data.iloc[:, -1]
# Out:
# 0          0
# 1          1
# 2          1
# 3          1
# 4          1
#           ..
# 5999995    0
# 5999996    1
# 5999997    0
# 5999998    0
# 5999999    1
# Name: Fraudulent Flag, Length: 6000000, dtype: int64

# %%
data['Transaction ID'].nunique()
# Out:
# 5805013

# %%
len(data)
# Out:
# 6000000

# %%
print('The different payment methods')
print(data['Payment Method'].unique())
print(data['Payment Method'].nunique())
print('\n')

print('The different country codes')
print(data['Country Code'].unique())
print(data['Country Code'].nunique())
print('\n')

print('The different transaction types')
print(data['Transaction Type'].unique())
print(data['Transaction Type'].nunique())
print('\n')

print('The different device type')
print(data['Device Type'].unique())
print(data['Device Type'].nunique())
print('\n')

print('The different Genders')
print(data['User Gender'].unique())
print(data['User Gender'].nunique())
# Out:
# The different payment methods
# ['ACH Transfer' '2Checkout' 'Google Wallet' 'Check' 'Worldpay'
#  'Prepaid Card' 'Credit Card' 'Contactless Payment' 'Masterpass' 'Venmo'
#  'E-check' 'NFC Payment' 'Direct Debit' 'Square Cash' 'Klarna' 'Afterpay'
#  'Apple Pay' 'Visa Checkout' 'Neteller' 'Wire Transfer' 'Western Union'
#  'Money Order' 'Stripe' 'Bank Transfer' 'Skrill' 'PayPal' 'Bitcoin'
#  'Mobile Wallet' 'Discover' 'WeChat Pay' 'Diners Club' 'Alipay' 'Ethereum'
#  'Cryptocurrency Wallet' 'Debit Card' 'Cash' 'JCB' 'Amazon Pay'
#  'American Express' 'Payoneer']
# 40
#
#
# The different country codes
# ['KOR' 'VNM' 'MEX' 'SGP' 'HKG' 'THA' 'CHE' 'CAN' 'TAI' 'QAT' 'JPN' 'USA'
#  'BRA' 'IDN' 'EGY' 'GER' 'BEL' 'AUT' 'IND' 'NZL' 'NGA' 'ESP' 'SAU' 'ISR'
#  'MAL' 'UK' 'NLD' 'SWE' 'FRA' 'AUS' 'ARG' 'GRE' 'CHN' 'NOR' 'TUR' 'RUS'
#  'ITA' 'POL' 'UAE' 'ZAF']
# 40
#
#
# The different transaction types
# ['Charity' 'Cashback' 'Reward' 'Purchase' 'Acquisition' 'Auction'
#  'Admission' 'Dividend' 'Recharge' 'Rental' 'Donation' 'Royalty' 'Expense'
#  'Tax' 'Payout' 'Registration Fee' 'Buyback' 'Rent' 'Interest'
#  'Withdrawal' 'Gift' 'Settlement' 'Subscription' 'Payment' 'Bonus'
#  'Transfer' 'Fine' 'Compensation' 'Contribution' 'Reimbursement' 'Invoice'
#  'Refund' 'Investment' 'Service Charge' 'Scholarship' 'Loan' 'Membership'
#  'Deposit']
# 38
#
#
# The different device type
# ['GPS Device' 'Medical Device' 'Vehicle Infotainment System' 'Kiosk'
#  'Smart Mirror' 'Smart Doorbell' 'Smart Speaker' 'Desktop'
#  'Home Security System' 'POS Terminal' 'Cash Register' 'Tablet'
#  'Wearable Device' 'Home Automation Hub' 'Industrial Controller' 'ATM'
#  'Smart Thermostat' 'Barcode Scanner' 'Server' 'Virtual Reality Headset'
#  'E-Reader' 'Smartphone' 'Smartwatch' 'Smart TV' 'Mobile' 'Digital Camera'
#  'Robot' 'Laptop' 'Fitness Tracker' 'Smart Lock' 'Gaming Console'
#  'Embedded System' 'IoT Device' 'Vending Machine' 'Self-Checkout Kiosk'
#  'Drone' 'Smart Appliance' 'Augmented Reality Glasses']
# 38
#
#
# The different Genders
# ['Prefer Not to Say' 'Genderqueer' 'Male' 'Agender' 'Other' 'Female'
#  'Non-Binary']
# 7

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6000000 entries, 0 to 5999999
# Data columns (total 32 columns):
#  #   Column                             Dtype
# ---  ------                             -----
#  0   Transaction ID                     int64
#  1   User ID                            int64
#  2   Transaction Amount                 float64
#  3   Transaction Date and Time          object
#  4   Merchant ID                        int64
#  5   Payment Method                     object
#  6   Country Code                       object
#  7   Transaction Type                   object
#  8   Device Type                        object
#  9   IP Address                         object
#  10  Browser Type                       object
#  11  Operating System                   object
#  12  Merchant Category                  object
#  13  User Age                           int64
#  14  User Occupation                    object
#  15  User Income                        float64
#  16  User Gender                        object
#  17  User Account Status                object
#  18  Transaction Status                 object
#  19  Location Distance                  float64
#  20  Time Taken for Transaction         float64
#  21  Transaction Time of Day            object
#  22  User's Transaction History         int64
#  23  Merchant's Reputation Score        float64
#  24  User's Device Location             object
#  25  Transaction Currency               object
#  26  Transaction Purpose                object
#  27  User's Credit Score                int64
#  28  User's Email Domain                object
#  29  Merchant's Business Age            int64
#  30  Transaction Authentication Method  object
#  31  Fraudulent Flag                    int64
# dtypes: float64(5), int64(8), object(19)
# memory usage: 1.4+ GB

# %% [markdown]
# ### DATA CLEANING

# %% [markdown]
# I'd look into every cell to find out if there is a cell with missing values. This is done in the code below

# %%
if data.isna().any().any():
    print("There are missing values in the DataFrame.")
else:
    print("There are no missing values in the DataFrame.")
# Out:
# There are no missing values in the DataFrame.

# %% [markdown]
# There are no missing values in the DataFrame.
# Next, I'll check for duplicates

# %%
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# There are no duplicates in the dataset
#
# Now, it's time to drop some of the columns

# %%
columns_to_drop = ['User ID', "User's Email Domain", 'IP Address']
data.drop(columns=columns_to_drop, inplace=True)

# %% [markdown]
# ### EXPLORATORY DATA ANALYSIS

# %% [markdown]
# First, I want to see the number of fraud activities and the number of legit activities then I'd compare them to one another, but before I do that I have to ensure that there is a column with unique values for me to use and verify the proportions. This would be shown below for better clarification.

# %%
data['Transaction ID'].nunique()
# Out:
# 5805013

# %% [markdown]
# We can see now that the transaction column does not have complete unique values. Are these duplicates? or are they independent rows. The code below showcases this

# %%
column_to_filter = 'Transaction ID'
value_to_match = 50746565

# Filter and display rows where the specified column has the specified value
filtered_rows = data[data[column_to_filter] == value_to_match]

# Print the filtered rows
df = pd.DataFrame(filtered_rows)
df.head()
# Out:
#          Transaction ID  Transaction Amount Transaction Date and Time  \
# 13             50746565              641.98       2022-06-28 12:09:26
# 4469207        50746565              402.86       2023-06-14 14:51:13
#
#          Merchant ID Payment Method Country Code Transaction Type Device Type  \
# 13              1186  Google Wallet          IDN          Expense      Tablet
# 4469207         4655      2Checkout          USA          Royalty       Robot
#
#         Browser Type Operating System  ... Transaction Time of Day  \
# 13         Konqueror             Unix  ...               Nighttime
# 4469207       Chrome     macOS Server  ...                 Evening
#
#          User's Transaction History Merchant's Reputation Score  \
# 13                               86                        1.79
# 4469207                          68                        3.35
#
#          User's Device Location Transaction Currency Transaction Purpose  \
# 13                       Sweden                  AUD     Retail Purchase
# 4469207                  Greece                  KES    Interest Payment
#
#         User's Credit Score  Merchant's Business Age  \
# 13                      373                       11
# 4469207                 712                        2
#
#          Transaction Authentication Method Fraudulent Flag
# 13        Certificate-based Authentication               0
# 4469207                        Retina Scan               1
#
# [2 rows x 29 columns]

# %% [markdown]
# Now, from the two simple rows in the dataframe above, we can see that although the transaction IDs are the same, they do not hold the samme information. The next thing we would do is create a column that holds a unique for every row so we can use the column to get our proprtion

# %%
data['Transaction_ID'] = range(1, len(data) + 1)

# %%
# lets check if the column has been created
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6000000 entries, 0 to 5999999
# Data columns (total 30 columns):
#  #   Column                             Dtype
# ---  ------                             -----
#  0   Transaction ID                     int64
#  1   Transaction Amount                 float64
#  2   Transaction Date and Time          object
#  3   Merchant ID                        int64
#  4   Payment Method                     object
#  5   Country Code                       object
#  6   Transaction Type                   object
#  7   Device Type                        object
#  8   Browser Type                       object
#  9   Operating System                   object
#  10  Merchant Category                  object
#  11  User Age                           int64
#  12  User Occupation                    object
#  13  User Income                        float64
#  14  User Gender                        object
#  15  User Account Status                object
#  16  Transaction Status                 object
#  17  Location Distance                  float64
#  18  Time Taken for Transaction         float64
#  19  Transaction Time of Day            object
#  20  User's Transaction History         int64
#  21  Merchant's Reputation Score        float64
#  22  User's Device Location             object
#  23  Transaction Currency               object
#  24  Transaction Purpose                object
#  25  User's Credit Score                int64
#  26  Merchant's Business Age            int64
#  27  Transaction Authentication Method  object
#  28  Fraudulent Flag                    int64
#  29  Transaction_ID                     int64
# dtypes: float64(5), int64(8), object(17)
# memory usage: 1.3+ GB

# %% [markdown]
# Now, we can use the Transaction ID column we created for the analysis as seen below

# %%
total_bids = data['Transaction_ID'].nunique()

# proportions
legitimate = len(data[data['Fraudulent Flag'] == 0.0])
fraudulent = len(data[data['Fraudulent Flag'] == 1.0])

legit = legitimate/total_bids
fraud = fraudulent/total_bids

# print
print("Proportion of legitimate bids: {:.2%}".format(legit))
print("Proportion of fraudulent bids: {:.2%}".format(fraud))
# Out:
# Proportion of legitimate bids: 50.00%
# Proportion of fraudulent bids: 50.00%

# %% [markdown]
# Now, let's view this properly with a pie chart

# %%
colors = ['darkseagreen', 'mediumseagreen']

# Pie chart parameters
pie_data = [legit, fraud]
pie_labels = ('Legit', 'Fraud')
pie_labels_explode_coefficients = (0, 0.175)

# Create the pie chart
plt.figure(figsize=(9, 7))
plt.pie(pie_data, labels=pie_labels, autopct='%1.2f%%', colors=colors,
        shadow=False, explode=pie_labels_explode_coefficients, textprops={'fontsize': 16})
plt.title("Proportion of Legitimate vs. Fraudulent", fontsize=18)
plt.axis('equal')
plt.show()

# %% [markdown]
# As seen from the chart above, we have a balanced data. The number frudulent data and legitimate data are both equal but to be sure, lets look at this using a histogram too

# %%
# Calculate value counts
value_counts = data['Fraudulent Flag'].value_counts()

# Create a bar plot
plt.bar(value_counts.index, value_counts.values)
plt.xlabel('Binary Values')
plt.ylabel('Count')
plt.title('Distribution of Binary Column')
plt.xticks(value_counts.index, ['0', '1'])
# Out:
# ([<matplotlib.axis.XTick at 0x7cbc22bf0370>,
#   <matplotlib.axis.XTick at 0x7cbc22bf0340>],
#  [Text(0, 0, '0'), Text(1, 0, '1')])

# %% [markdown]
# The 'Fraudulent Flag' column is normally distributed
#
#
# Using charts, lets see some of the properties of the data

# %%
value_counts = data['User Gender'].value_counts()

# Create a bar chart to visualize the counts
plt.bar(value_counts.index, value_counts.values)

# Add labels and a title
plt.xlabel('User Gender')
plt.ylabel('Count')
plt.title('Value Counts of User Gender')

# Show the plot
plt.show()

# %% [markdown]
# Now, let's look at the spread of the data
#
# Let's look at the mean, median and mode of some of the numerical data

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6000000 entries, 0 to 5999999
# Data columns (total 30 columns):
#  #   Column                             Dtype
# ---  ------                             -----
#  0   Transaction ID                     int64
#  1   Transaction Amount                 float64
#  2   Transaction Date and Time          object
#  3   Merchant ID                        int64
#  4   Payment Method                     object
#  5   Country Code                       object
#  6   Transaction Type                   object
#  7   Device Type                        object
#  8   Browser Type                       object
#  9   Operating System                   object
#  10  Merchant Category                  object
#  11  User Age                           int64
#  12  User Occupation                    object
#  13  User Income                        float64
#  14  User Gender                        object
#  15  User Account Status                object
#  16  Transaction Status                 object
#  17  Location Distance                  float64
#  18  Time Taken for Transaction         float64
#  19  Transaction Time of Day            object
#  20  User's Transaction History         int64
#  21  Merchant's Reputation Score        float64
#  22  User's Device Location             object
#  23  Transaction Currency               object
#  24  Transaction Purpose                object
#  25  User's Credit Score                int64
#  26  Merchant's Business Age            int64
#  27  Transaction Authentication Method  object
#  28  Fraudulent Flag                    int64
#  29  Transaction_ID                     int64
# dtypes: float64(5), int64(8), object(17)
# memory usage: 1.3+ GB

# %%
# Grouped data
data_grouped_by = data.groupby(['Transaction_ID'])

# Columns to loop through
features = [('Payment Methods', 'Payment Method'), ('Device Types', 'Device Type'), ('User Ages', 'User Age'),
            ('User Occupations', 'User Occupation'), ('User Incomes', 'User Income'), ("Merchant's Reputation Scores", "Merchant's Reputation Score")]

for name, column in features:
    stats = data_grouped_by[column].nunique()

    # Calculate mean, median, mode, min and max for humans and robots
    print("Mean of {} per user: {:.2f}".format(name, stats.mean()))
    print("Median of {} per user: {}".format(name, stats.median()))
    print("Mode of {} per user: {}".format(name, stats.mode()[0]))
    print("User with more {}: {}".format(name, stats.max()))
    print("User with less {}: {}".format(name, stats.min()))
    print('----------------------------------')
# Out:
# Mean of Payment Methods per user: 1.00
# Median of Payment Methods per user: 1.0
# Mode of Payment Methods per user: 1
# User with more Payment Methods: 1
# User with less Payment Methods: 1
# ----------------------------------
# Mean of Device Types per user: 1.00
# Median of Device Types per user: 1.0
# Mode of Device Types per user: 1
# User with more Device Types: 1
# User with less Device Types: 1
# ----------------------------------
# Mean of User Ages per user: 1.00
# Median of User Ages per user: 1.0
# Mode of User Ages per user: 1
# User with more User Ages: 1
# User with less User Ages: 1
# ----------------------------------
# Mean of User Occupations per user: 1.00
# Median of User Occupations per user: 1.0
# Mode of User Occupations per user: 1
# User with more User Occupations: 1
# User with less User Occupations: 1
# ----------------------------------
# Mean of User Incomes per user: 1.00
# Median of User Incomes per user: 1.0
# Mode of User Incomes per user: 1
# User with more User Incomes: 1
# User with less User Incomes: 1
# ----------------------------------
# Mean of Merchant's Reputation Scores per user: 1.00
# Median of Merchant's Reputation Scores per user: 1.0
# Mode of Merchant's Reputation Scores per user: 1
# User with more Merchant's Reputation Scores: 1
# User with less Merchant's Reputation Scores: 1
# ----------------------------------

# %% [markdown]
# Now, let's do a fraudulent/legit comparison

# %% [markdown]
# __Payment Method__

# %%
payment_df = data[['Payment Method', 'Fraudulent Flag']]

# Creating a pivot table with payment method as index, outcome as columns and count of fraudulent flag as values
payment_human_bot = payment_df.pivot_table(values='Fraudulent Flag', index='Payment Method', columns='Fraudulent Flag', fill_value=0,
                         aggfunc=lambda x: len(x))

# Passing the pivot table to heatmap for visualization
payment_human_bot.style.background_gradient(cmap ='Blues', axis=0)
# Out:
# <style type="text/css">
# #T_578ee_row0_col0, #T_578ee_row3_col0 {
#   background-color: #1562a9;
#   color: #f1f1f1;
# }
# #T_578ee_row0_col1 {
#   background-color: #9ac8e0;
#   color: #000000;
# }
# #T_578ee_row1_col0 {
#   background-color: #dbe9f6;
#   color: #000000;
# }
# #T_578ee_row1_col1 {
#   background-color: #6dafd7;
#   color: #f1f1f1;
# }
# #T_578ee_row2_col0 {
#   background-color: #0a549e;
#   color: #f1f1f1;
# }
# #T_578ee_row2_col1 {
#   background-color: #1c6ab0;
#   color: #f1f1f1;
# }
# #T_578ee_row3_col1 {
#   background-color: #4191c6;
#   color: #f1f1f1;
# }
# #T_578ee_row4_col0 {
#   background-color: #0e59a2;
#   color: #f1f1f1;
# }
# #T_578ee_row4_col1, #T_578ee_row14_col0 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_578ee_row5_col0, #T_578ee_row16_col0 {
#   background-color: #b9d6ea;
#   color: #000000;
# }
# #T_578ee_row5_col1 {
#   background-color: #2777b8;
#   color: #f1f1f1;
# }
# #T_578ee_row6_col0, #T_578ee_row12_col0 {
#   background-color: #8dc1dd;
#   color: #000000;
# }
# #T_578ee_row6_col1 {
#   background-color: #1b69af;
#   color: #f1f1f1;
# }
# #T_578ee_row7_col0 {
#   background-color: #8abfdd;
#   color: #000000;
# }
# #T_578ee_row7_col1 {
#   background-color: #2a7ab9;
#   color: #f1f1f1;
# }
# #T_578ee_row8_col0 {
#   background-color: #cbdef1;
#   color: #000000;
# }
# #T_578ee_row8_col1, #T_578ee_row23_col1 {
#   background-color: #084c95;
#   color: #f1f1f1;
# }
# #T_578ee_row9_col0 {
#   background-color: #5da5d1;
#   color: #f1f1f1;
# }
# #T_578ee_row9_col1 {
#   background-color: #e5eff9;
#   color: #000000;
# }
# #T_578ee_row10_col0 {
#   background-color: #9cc9e1;
#   color: #000000;
# }
# #T_578ee_row10_col1 {
#   background-color: #206fb4;
#   color: #f1f1f1;
# }
# #T_578ee_row11_col0 {
#   background-color: #a5cde3;
#   color: #000000;
# }
# #T_578ee_row11_col1 {
#   background-color: #1a68ae;
#   color: #f1f1f1;
# }
# #T_578ee_row12_col1, #T_578ee_row33_col1 {
#   background-color: #3383be;
#   color: #f1f1f1;
# }
# #T_578ee_row13_col0 {
#   background-color: #09529d;
#   color: #f1f1f1;
# }
# #T_578ee_row13_col1 {
#   background-color: #0e58a2;
#   color: #f1f1f1;
# }
# #T_578ee_row14_col1 {
#   background-color: #7fb9da;
#   color: #000000;
# }
# #T_578ee_row15_col0 {
#   background-color: #2373b6;
#   color: #f1f1f1;
# }
# #T_578ee_row15_col1, #T_578ee_row25_col1 {
#   background-color: #4493c7;
#   color: #f1f1f1;
# }
# #T_578ee_row16_col1, #T_578ee_row18_col1 {
#   background-color: #4896c8;
#   color: #f1f1f1;
# }
# #T_578ee_row17_col0 {
#   background-color: #afd1e7;
#   color: #000000;
# }
# #T_578ee_row17_col1 {
#   background-color: #add0e6;
#   color: #000000;
# }
# #T_578ee_row18_col0, #T_578ee_row24_col1 {
#   background-color: #08326e;
#   color: #f1f1f1;
# }
# #T_578ee_row19_col0 {
#   background-color: #3282be;
#   color: #f1f1f1;
# }
# #T_578ee_row19_col1 {
#   background-color: #2c7cba;
#   color: #f1f1f1;
# }
# #T_578ee_row20_col0, #T_578ee_row22_col1 {
#   background-color: #d0e2f2;
#   color: #000000;
# }
# #T_578ee_row20_col1 {
#   background-color: #2070b4;
#   color: #f1f1f1;
# }
# #T_578ee_row21_col0 {
#   background-color: #74b3d8;
#   color: #000000;
# }
# #T_578ee_row21_col1, #T_578ee_row28_col1 {
#   background-color: #b3d3e8;
#   color: #000000;
# }
# #T_578ee_row22_col0 {
#   background-color: #4695c8;
#   color: #f1f1f1;
# }
# #T_578ee_row23_col0, #T_578ee_row31_col1, #T_578ee_row37_col0 {
#   background-color: #4090c5;
#   color: #f1f1f1;
# }
# #T_578ee_row24_col0 {
#   background-color: #91c3de;
#   color: #000000;
# }
# #T_578ee_row25_col0 {
#   background-color: #a8cee4;
#   color: #000000;
# }
# #T_578ee_row26_col0 {
#   background-color: #1f6eb3;
#   color: #f1f1f1;
# }
# #T_578ee_row26_col1, #T_578ee_row30_col0 {
#   background-color: #a6cee4;
#   color: #000000;
# }
# #T_578ee_row27_col0 {
#   background-color: #4e9acb;
#   color: #f1f1f1;
# }
# #T_578ee_row27_col1 {
#   background-color: #c7dbef;
#   color: #000000;
# }
# #T_578ee_row28_col0, #T_578ee_row37_col1 {
#   background-color: #d6e6f4;
#   color: #000000;
# }
# #T_578ee_row29_col0 {
#   background-color: #d9e8f5;
#   color: #000000;
# }
# #T_578ee_row29_col1 {
#   background-color: #ddeaf7;
#   color: #000000;
# }
# #T_578ee_row30_col1 {
#   background-color: #85bcdc;
#   color: #000000;
# }
# #T_578ee_row31_col0, #T_578ee_row34_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_578ee_row32_col0 {
#   background-color: #3d8dc4;
#   color: #f1f1f1;
# }
# #T_578ee_row32_col1 {
#   background-color: #a3cce3;
#   color: #000000;
# }
# #T_578ee_row33_col0 {
#   background-color: #5fa6d1;
#   color: #f1f1f1;
# }
# #T_578ee_row34_col0 {
#   background-color: #65aad4;
#   color: #f1f1f1;
# }
# #T_578ee_row35_col0 {
#   background-color: #4d99ca;
#   color: #f1f1f1;
# }
# #T_578ee_row35_col1 {
#   background-color: #1e6db2;
#   color: #f1f1f1;
# }
# #T_578ee_row36_col0 {
#   background-color: #75b4d8;
#   color: #000000;
# }
# #T_578ee_row36_col1 {
#   background-color: #7db8da;
#   color: #000000;
# }
# #T_578ee_row38_col0 {
#   background-color: #69add5;
#   color: #f1f1f1;
# }
# #T_578ee_row38_col1 {
#   background-color: #81badb;
#   color: #000000;
# }
# #T_578ee_row39_col0 {
#   background-color: #cadef0;
#   color: #000000;
# }
# #T_578ee_row39_col1 {
#   background-color: #519ccc;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_578ee" class="dataframe">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Fraudulent Flag</th>
#       <th id="T_578ee_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_578ee_level0_col1" class="col_heading level0 col1" >1</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Payment Method</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_578ee_level0_row0" class="row_heading level0 row0" >2Checkout</th>
#       <td id="T_578ee_row0_col0" class="data row0 col0" >75292</td>
#       <td id="T_578ee_row0_col1" class="data row0 col1" >74823</td>
#     </tr>
#     <tr>
#       <th id="T_578ee_level0_row1" class="row_heading level0 row1" >ACH Transfer</th>
#       <td id="T_578ee_row1_col0" class="data row1 col0" >74652</td>
#       <td id="T_578ee_row1_col1" class="data row1 col1" >74934</td>
#     </tr>
#     <tr>
#       <th id="T_578ee_level0_row2" class="row_heading level0 row2" >Afterpay</th>
#       <td id="T_578ee_row2_col0" class="data row2 col0" >75347</td>
#       <td id="T_578ee_row2_col1" class="data row2 col1" >75223</td>
#     </tr>
#     <tr>
#       <th id="T_578ee_level0_row3" class="row_heading level0 row3" >Alipay</th>
#       <td id="T_578ee_row3_col0" class="data row3 col0" >75293</td>
#       <td id="T_578ee_row3_col1" class="data row3 col1" >75073</td>
#     </tr>
#     <tr>
#       <th id="T_578ee_level0_row4" class="row_heading level0 row4" >Amazon Pay</th>
#       <td id="T_578ee_row4_col0" class="data row4 col0" >75327</td>
#       <td id="T_578ee_row4_col1" class="data row4 col1" >75454</td>
#     </tr>
#     <tr>
#       <th id="T_578ee_level0_row5" class="row_heading level0 row5" >American Express</th>
#       <td id="T_578ee_row5_col0" class="data row5 col0" >74794</td>
#       <td id="T_578ee_row5_col1" class="data row5 col1" >75170</td>
#     </tr>
#     <tr>
#       <th id="T_578ee_level0_row6" class="row_heading level0 row6" >Apple Pay</th>
#       <td id="T_578ee_row6_col0" class="data row6 col0" >74916</td>
#       <td id="T_578ee_row6_col1" class="data row6 col1" >75227</td>
#     </tr>
#     <tr>
#       <th id="T_578ee_level0_row7" class="row_heading level0 row7" >Bank Transfer</th>
#       <td id="T_578ee_row7_col0" class="data row7 col0" >74923</td>
#       <td id="T_578ee_row7_col1" class="data row7 col1" >75165</td>
#     </tr>
#     <tr>
#       <th id="T_578ee_level0_row8" class="row_heading level0 row8" >Bitcoin</th>
#       <td id="T_578ee_row8_col0" class="data row8 col0" >74733</td>
#       <td id="T_578ee_row8_col1" class="data row8 col1" >75343</td>
#     </tr>
#     <tr>
#       <th id="T_578ee_level0_row9" class="row_heading level0 row9" >Cash</th>
#       <td id="T_578ee_row9_col0" class="data row9 col0" >75038</td>
#       <td id="T_578ee_row9_col1" class="data row9 col1" >74525</td>
#     </tr>
#     <tr>
#       <th id="T_578ee_level0_row10" class="row_heading level0 row10" >Check</th>
#       <td id="T_578ee_row10_col0" class="data row10 col0" >74884</td>
#       <td id="T_578ee_row10_col1" class="data row10 col1" >75202</td>
#     </tr>
#     <tr>
#       <th id="T_5

# %% [markdown]
# __Device type__

# %%
device_df = data[['Device Type', 'Fraudulent Flag']]

# Creating a pivot table with device type as index, outcome as columns and count of fraudulent flag as values
device_human_bot = device_df.pivot_table(values='Fraudulent Flag', index='Device Type', columns='Fraudulent Flag', fill_value=0,
                         aggfunc=lambda x: len(x))

# Passing the pivot table to heatmap for visualization
device_human_bot.style.background_gradient(cmap ='Blues', axis=0)
# Out:
# <style type="text/css">
# #T_73c09_row0_col0, #T_73c09_row1_col0 {
#   background-color: #77b5d9;
#   color: #000000;
# }
# #T_73c09_row0_col1 {
#   background-color: #2474b7;
#   color: #f1f1f1;
# }
# #T_73c09_row1_col1, #T_73c09_row12_col0 {
#   background-color: #539ecd;
#   color: #f1f1f1;
# }
# #T_73c09_row2_col0 {
#   background-color: #58a1cf;
#   color: #f1f1f1;
# }
# #T_73c09_row2_col1 {
#   background-color: #2272b6;
#   color: #f1f1f1;
# }
# #T_73c09_row3_col0, #T_73c09_row32_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_73c09_row3_col1 {
#   background-color: #4594c7;
#   color: #f1f1f1;
# }
# #T_73c09_row4_col0 {
#   background-color: #3787c0;
#   color: #f1f1f1;
# }
# #T_73c09_row4_col1, #T_73c09_row8_col1, #T_73c09_row35_col1 {
#   background-color: #cadef0;
#   color: #000000;
# }
# #T_73c09_row5_col0, #T_73c09_row30_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_73c09_row5_col1 {
#   background-color: #9cc9e1;
#   color: #000000;
# }
# #T_73c09_row6_col0 {
#   background-color: #4f9bcb;
#   color: #f1f1f1;
# }
# #T_73c09_row6_col1 {
#   background-color: #1d6cb1;
#   color: #f1f1f1;
# }
# #T_73c09_row7_col0 {
#   background-color: #a6cee4;
#   color: #000000;
# }
# #T_73c09_row7_col1 {
#   background-color: #3d8dc4;
#   color: #f1f1f1;
# }
# #T_73c09_row8_col0, #T_73c09_row23_col0, #T_73c09_row27_col1 {
#   background-color: #3282be;
#   color: #f1f1f1;
# }
# #T_73c09_row9_col0, #T_73c09_row37_col1 {
#   background-color: #08458a;
#   color: #f1f1f1;
# }
# #T_73c09_row9_col1, #T_73c09_row16_col0, #T_73c09_row25_col0, #T_73c09_row31_col1 {
#   background-color: #1562a9;
#   color: #f1f1f1;
# }
# #T_73c09_row10_col0, #T_73c09_row34_col1 {
#   background-color: #6caed6;
#   color: #f1f1f1;
# }
# #T_73c09_row10_col1 {
#   background-color: #105ba4;
#   color: #f1f1f1;
# }
# #T_73c09_row11_col0 {
#   background-color: #68acd5;
#   color: #f1f1f1;
# }
# #T_73c09_row11_col1 {
#   background-color: #1f6eb3;
#   color: #f1f1f1;
# }
# #T_73c09_row12_col1, #T_73c09_row19_col0, #T_73c09_row34_col0 {
#   background-color: #69add5;
#   color: #f1f1f1;
# }
# #T_73c09_row13_col0 {
#   background-color: #6fb0d7;
#   color: #f1f1f1;
# }
# #T_73c09_row13_col1 {
#   background-color: #6aaed6;
#   color: #f1f1f1;
# }
# #T_73c09_row14_col0, #T_73c09_row33_col1 {
#   background-color: #3989c1;
#   color: #f1f1f1;
# }
# #T_73c09_row14_col1, #T_73c09_row37_col0 {
#   background-color: #a1cbe2;
#   color: #000000;
# }
# #T_73c09_row15_col0 {
#   background-color: #09529d;
#   color: #f1f1f1;
# }
# #T_73c09_row15_col1 {
#   background-color: #1460a8;
#   color: #f1f1f1;
# }
# #T_73c09_row16_col1, #T_73c09_row20_col0, #T_73c09_row35_col0 {
#   background-color: #4695c8;
#   color: #f1f1f1;
# }
# #T_73c09_row17_col0 {
#   background-color: #2b7bba;
#   color: #f1f1f1;
# }
# #T_73c09_row17_col1 {
#   background-color: #92c4de;
#   color: #000000;
# }
# #T_73c09_row18_col0 {
#   background-color: #084d96;
#   color: #f1f1f1;
# }
# #T_73c09_row18_col1 {
#   background-color: #e0ecf8;
#   color: #000000;
# }
# #T_73c09_row19_col1 {
#   background-color: #125da6;
#   color: #f1f1f1;
# }
# #T_73c09_row20_col1 {
#   background-color: #2373b6;
#   color: #f1f1f1;
# }
# #T_73c09_row21_col0, #T_73c09_row32_col0 {
#   background-color: #c1d9ed;
#   color: #000000;
# }
# #T_73c09_row21_col1 {
#   background-color: #ddeaf7;
#   color: #000000;
# }
# #T_73c09_row22_col0 {
#   background-color: #7cb7da;
#   color: #000000;
# }
# #T_73c09_row22_col1 {
#   background-color: #3383be;
#   color: #f1f1f1;
# }
# #T_73c09_row23_col1, #T_73c09_row24_col1 {
#   background-color: #65aad4;
#   color: #f1f1f1;
# }
# #T_73c09_row24_col0 {
#   background-color: #135fa7;
#   color: #f1f1f1;
# }
# #T_73c09_row25_col1 {
#   background-color: #7ab6d9;
#   color: #000000;
# }
# #T_73c09_row26_col0 {
#   background-color: #add0e6;
#   color: #000000;
# }
# #T_73c09_row26_col1 {
#   background-color: #a4cce3;
#   color: #000000;
# }
# #T_73c09_row27_col0, #T_73c09_row30_col0 {
#   background-color: #c6dbef;
#   color: #000000;
# }
# #T_73c09_row28_col0 {
#   background-color: #206fb4;
#   color: #f1f1f1;
# }
# #T_73c09_row28_col1, #T_73c09_row36_col1 {
#   background-color: #3f8fc5;
#   color: #f1f1f1;
# }
# #T_73c09_row29_col0 {
#   background-color: #084990;
#   color: #f1f1f1;
# }
# #T_73c09_row29_col1 {
#   background-color: #084a91;
#   color: #f1f1f1;
# }
# #T_73c09_row31_col0 {
#   background-color: #f4f9fe;
#   color: #000000;
# }
# #T_73c09_row33_col0 {
#   background-color: #82bbdb;
#   color: #000000;
# }
# #T_73c09_row36_col0 {
#   background-color: #b7d4ea;
#   color: #000000;
# }
# </style>
# <table id="T_73c09" class="dataframe">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Fraudulent Flag</th>
#       <th id="T_73c09_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_73c09_level0_col1" class="col_heading level0 col1" >1</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Device Type</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_73c09_level0_row0" class="row_heading level0 row0" >ATM</th>
#       <td id="T_73c09_row0_col0" class="data row0 col0" >78858</td>
#       <td id="T_73c09_row0_col1" class="data row0 col1" >79140</td>
#     </tr>
#     <tr>
#       <th id="T_73c09_level0_row1" class="row_heading level0 row1" >Augmented Reality Glasses</th>
#       <td id="T_73c09_row1_col0" class="data row1 col0" >78858</td>
#       <td id="T_73c09_row1_col1" class="data row1 col1" >78943</td>
#     </tr>
#     <tr>
#       <th id="T_73c09_level0_row2" class="row_heading level0 row2" >Barcode Scanner</th>
#       <td id="T_73c09_row2_col0" class="data row2 col0" >78957</td>
#       <td id="T_73c09_row2_col1" class="data row2 col1" >79152</td>
#     </tr>
#     <tr>
#       <th id="T_73c09_level0_row3" class="row_heading level0 row3" >Cash Register</th>
#       <td id="T_73c09_row3_col0" class="data row3 col0" >79468</td>
#       <td id="T_73c09_row3_col1" class="data row3 col1" >78996</td>
#     </tr>
#     <tr>
#       <th id="T_73c09_level0_row4" class="row_heading level0 row4" >Desktop</th>
#       <td id="T_73c09_row4_col0" class="data row4 col0" >79084</td>
#       <td id="T_73c09_row4_col1" class="data row4 col1" >78523</td>
#     </tr>
#     <tr>
#       <th id="T_73c09_level0_row5" class="row_heading level0 row5" >Digital Camera</th>
#       <td id="T_73c09_row5_col0" class="data row5 col0" >78319</td>
#       <td id="T_73c09_row5_col1" class="data row5 col1" >78709</td>
#     </tr>
#     <tr>
#       <th id="T_73c09_level0_row6" class="row_heading level0 row6" >Drone</th>
#       <td id="T_73c09_row6_col0" class="data row6 col0" >78989</td>
#       <td id="T_73c09_row6_col1" class="data row6 col1" >79181</td>
#     </tr>
#     <tr>
#       <th id="T_73c09_level0_row7" class="row_heading level0 row7" >E-Reader</th>
#       <td id="T_73c09_row7_col0" class="data row7 col0" >78721</td>
#       <td id="T_73c09_row7_col1" class="data row7 col1" >79026</td>
#     </tr>
#     <tr>
#       <th id="T_73c09_level0_row8" class="row_heading level0 row8" >Embedded System</th>
#       <td id="T_73c09_row8_col0" class="data row8 col0" >79108</td>
#       <td id="T_73c09_row8_col1" class="data row8 col1" >78525</td>
#     </tr>
#     <tr>
#       <th id="T_73c09_level0_row9" class="row_heading level0 row9" >Fitness Tracker</th>
#       <td id="T_73c09_row9_col0" class="data row9 col0" >79378</td>
#       <td id="T_73c09_row9_col1" class="data row9 col1" >79227</td>
#     </tr>
#     <tr>
#       <th id="T_73c09_level0_row10" class="row_heading level0 row10" >GPS Device</th>
#       <td id="T_73c09_row10_col0" class="data row10 col0" >78891</td>
#       <td id="T_73c09_row10_col1" class="data row10 col1" >79262</td>
#     </tr>
#     <tr>
#       <th id="T_73c09_level0_row11" class="row_heading level0 row11" >Gaming Console</th>
#       <td id="T_73c09_row11_col0" class="data row11 col0" >78904</td>
#       <td id="T_73c09_row11_col1" class="data row11 col1" >79169</td>
#     </tr>
#     <tr>
#       <th id="T_73c09_level0_row12" class="row_heading level0 row12" >Home Automation Hub</th>
#       <td id="T_73c09_row12_col0" class="data row12 col0" >78976</td>
#       <td id="T_73c09_row12_col1" class="data row12 col1" >78861</td>
#     </tr>
#     <tr>
#       <th id="T_73c09_level0_row13" class="row_heading level0 row13" >Home Security System</th>
#       <td id="T_73c09_ro

# %% [markdown]
# __Browser Type__

# %%
browser_df = data[['Browser Type', 'Fraudulent Flag']]

# Creating a pivot table with browzer as index, outcome as columns and count of fraudulent as values
browser_human_bot = browser_df.pivot_table(values='Fraudulent Flag', index='Browser Type', columns='Fraudulent Flag', fill_value=0,
                         aggfunc=lambda x: len(x))

# Passing the pivot table to heatmap for visualization
browser_human_bot.style.background_gradient(cmap ='Blues', axis=0)
# Out:
# <style type="text/css">
# #T_180ef_row0_col0, #T_180ef_row1_col1, #T_180ef_row2_col0, #T_180ef_row4_col1, #T_180ef_row8_col1, #T_180ef_row10_col1, #T_180ef_row11_col1, #T_180ef_row12_col1, #T_180ef_row16_col1, #T_180ef_row17_col1, #T_180ef_row19_col0, #T_180ef_row19_col1, #T_180ef_row21_col1, #T_180ef_row25_col0, #T_180ef_row25_col1, #T_180ef_row27_col1, #T_180ef_row32_col1, #T_180ef_row34_col1, #T_180ef_row35_col1 {
#   background-color: #f6faff;
#   color: #000000;
# }
# #T_180ef_row0_col1, #T_180ef_row2_col1, #T_180ef_row3_col1, #T_180ef_row4_col0, #T_180ef_row6_col0, #T_180ef_row6_col1, #T_180ef_row7_col0, #T_180ef_row8_col0, #T_180ef_row9_col0, #T_180ef_row12_col0, #T_180ef_row15_col1, #T_180ef_row20_col0, #T_180ef_row22_col1, #T_180ef_row23_col0, #T_180ef_row26_col1, #T_180ef_row28_col0, #T_180ef_row28_col1, #T_180ef_row29_col0, #T_180ef_row31_col0, #T_180ef_row31_col1, #T_180ef_row32_col0, #T_180ef_row33_col0, #T_180ef_row36_col1, #T_180ef_row37_col1, #T_180ef_row38_col1 {
#   background-color: #f5fafe;
#   color: #000000;
# }
# #T_180ef_row1_col0, #T_180ef_row3_col0, #T_180ef_row10_col0, #T_180ef_row11_col0, #T_180ef_row13_col0, #T_180ef_row13_col1, #T_180ef_row14_col0, #T_180ef_row14_col1, #T_180ef_row15_col0, #T_180ef_row16_col0, #T_180ef_row18_col0, #T_180ef_row18_col1, #T_180ef_row20_col1, #T_180ef_row21_col0, #T_180ef_row23_col1, #T_180ef_row26_col0, #T_180ef_row27_col0, #T_180ef_row30_col0, #T_180ef_row30_col1, #T_180ef_row34_col0, #T_180ef_row35_col0, #T_180ef_row36_col0, #T_180ef_row38_col0 {
#   background-color: #f5f9fe;
#   color: #000000;
# }
# #T_180ef_row5_col0, #T_180ef_row22_col0 {
#   background-color: #f4f9fe;
#   color: #000000;
# }
# #T_180ef_row5_col1, #T_180ef_row7_col1, #T_180ef_row9_col1, #T_180ef_row17_col0, #T_180ef_row29_col1, #T_180ef_row33_col1, #T_180ef_row37_col0 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_180ef_row24_col0, #T_180ef_row24_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_180ef" class="dataframe">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Fraudulent Flag</th>
#       <th id="T_180ef_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_180ef_level0_col1" class="col_heading level0 col1" >1</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Browser Type</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_180ef_level0_row0" class="row_heading level0 row0" >Avant Browser</th>
#       <td id="T_180ef_row0_col0" class="data row0 col0" >74715</td>
#       <td id="T_180ef_row0_col1" class="data row0 col1" >75281</td>
#     </tr>
#     <tr>
#       <th id="T_180ef_level0_row1" class="row_heading level0 row1" >Basilisk</th>
#       <td id="T_180ef_row1_col0" class="data row1 col0" >75264</td>
#       <td id="T_180ef_row1_col1" class="data row1 col1" >74839</td>
#     </tr>
#     <tr>
#       <th id="T_180ef_level0_row2" class="row_heading level0 row2" >Beaker</th>
#       <td id="T_180ef_row2_col0" class="data row2 col0" >74622</td>
#       <td id="T_180ef_row2_col1" class="data row2 col1" >75027</td>
#     </tr>
#     <tr>
#       <th id="T_180ef_level0_row3" class="row_heading level0 row3" >Brave</th>
#       <td id="T_180ef_row3_col0" class="data row3 col0" >75025</td>
#       <td id="T_180ef_row3_col1" class="data row3 col1" >75287</td>
#     </tr>
#     <tr>
#       <th id="T_180ef_level0_row4" class="row_heading level0 row4" >Browsh</th>
#       <td id="T_180ef_row4_col0" class="data row4 col0" >74745</td>
#       <td id="T_180ef_row4_col1" class="data row4 col1" >74799</td>
#     </tr>
#     <tr>
#       <th id="T_180ef_level0_row5" class="row_heading level0 row5" >Chrome</th>
#       <td id="T_180ef_row5_col0" class="data row5 col0" >75445</td>
#       <td id="T_180ef_row5_col1" class="data row5 col1" >74592</td>
#     </tr>
#     <tr>
#       <th id="T_180ef_level0_row6" class="row_heading level0 row6" >Chromium</th>
#       <td id="T_180ef_row6_col0" class="data row6 col0" >74938</td>
#       <td id="T_180ef_row6_col1" class="data row6 col1" >75293</td>
#     </tr>
#     <tr>
#       <th id="T_180ef_level0_row7" class="row_heading level0 row7" >Dooble</th>
#       <td id="T_180ef_row7_col0" class="data row7 col0" >74961</td>
#       <td id="T_180ef_row7_col1" class="data row7 col1" >74631</td>
#     </tr>
#     <tr>
#       <th id="T_180ef_level0_row8" class="row_heading level0 row8" >ELinks</th>
#       <td id="T_180ef_row8_col0" class="data row8 col0" >74970</td>
#       <td id="T_180ef_row8_col1" class="data row8 col1" >74791</td>
#     </tr>
#     <tr>
#       <th id="T_180ef_level0_row9" class="row_heading level0 row9" >Edge</th>
#       <td id="T_180ef_row9_col0" class="data row9 col0" >74876</td>
#       <td id="T_180ef_row9_col1" class="data row9 col1" >74688</td>
#     </tr>
#     <tr>
#       <th id="T_180ef_level0_row10" class="row_heading level0 row10" >Epiphany</th>
#       <td id="T_180ef_row10_col0" class="data row10 col0" >75270</td>
#       <td id="T_180ef_row10_col1" class="data row10 col1" >74739</td>
#     </tr>
#     <tr>
#       <th id="T_180ef_level0_row11" class="row_heading level0 row11" >Falkon</th>
#       <td id="T_180ef_row11_col0" class="data row11 col0" >75289</td>
#       <td id="T_180ef_row11_col1" class="data row11 col1" >74809</td>
#     </tr>
#     <tr>
#       <th id="T_180ef_level0_row12" class="row_heading level0 row12" >Firefox</th>
#       <td id="T_180ef_row12_col0" class="data row12 col0" >74759</td>
#       <td id="T_180ef_row12_col1" class="data row12 col1" >74804</td>
#     </tr>
#     <tr>
#       <th id="T_180ef_level0_row13" class="row_heading level0 row13" >Internet Explorer</th>
#       <td id="T_180ef_row13_col0" class="data row13 col0" >75059</td>
#       <td id="T_180ef_row13_col1" class="data row13 col1" >75378</td>
#     </tr>
#     <tr>
#       <th id="T_180ef_level0_row14" class="row_heading level0 row14" >Konqueror</th>
#       <td id="T_180ef_row14_col0" class="data row14 col0" >75127</td>
#       <td id="T_180ef_row14_col1" class="data row14 col1" >75340</td>
#     </tr>
#     <tr>
#       <th id="T_180ef_level0_row15" class="row_heading level0 row15" >Links</th>
#       <td id="T_180ef_row15_col0" class="data row15 col0" >75294</td>
#       <td id="T_180ef_row15_col1" class="data row15 col1" >75121</td>
#     </tr>
#     <tr>
#       <th id="T_180ef_level0_row16" class="row_heading level0 row16" >Lynx</th>
#       <td id="T_180ef_row16_col0" class="data row16 col0" >75153</td>
#       <td id="T_180ef_row16_col1" class="data row16 col1" >74969</td>
#     </tr>
#     <tr>
#       <th id="T_180ef_level0_row17" class="row_heading level0 row17" >Maxthon</th>
#       <td id="T_180ef_row17_col0" class="data row17 col0" >74130</td>
#       <td id="T_180ef_row17_col1" class="data row17 col1" >74760</td>
#     </tr>
#     <tr>
#       <th id="T_180ef_level0_row18" class="row_heading level0 row18" >Midori</th>
#       <td id="T_180ef_row18_col0" class="data row18 col0" >75107</td>
#       <td id="T_180ef_row18_col1" class="data row18 col1" >75373</td>
#     </tr>
#     <tr>
#       <th id="T_180ef_level0_row19" class="row_heading level0 row19" >Min</th>
#       <td id="T_180ef_row19_col0" class="data row19 col0" >74724</td>
#       <td id="T_180ef_row19_col1" class="data row19 col1" >74934</td>
#     </tr>
#     <tr>
#       <th id="T_180ef_level0_row20" class="row_heading level0 row20" >NetSurf</th>
#       <td id="T_180ef_row20_col0" class="data row20 col0" >74833</td>
#       <td id="T_180ef_row20_col1" class="data row20 col1" >75372</td>
#     </tr>
#     <tr>
#       <th id="T_180ef_level0_row21" class="row_heading level0 row21" >Opera</th>
#       <td id="T_180ef_row21_col0" class="data row21 col0" >75248</td>
#       <td id="T_180ef_row21_col1" class="data row21 col1" >74901</td>
#     </tr>
#     <tr>
#       <th id="T_180ef_level0_row22" class="row_heading level0 row22" >Otter Browser</th>
#       <td id="T_180ef_row22_col0" class="data row22 col0" >75368</td>
#       <td id="T_180ef_row22_col1" class="data row22 col1" >75207</td>
#     </tr>
#     <tr>
#       <th id="T_180ef_level0_row23" class="row_heading level0 row23" >Pale

# %% [markdown]
# __Operating System__

# %%
operating_df = data[['Operating System', 'Fraudulent Flag']]

# Creating a pivot table with operating system as index, outcome as columns and count of fraudulent as values
operating_human_bot = operating_df.pivot_table(values='Fraudulent Flag', index='Operating System', columns='Fraudulent Flag', fill_value=0,
                         aggfunc=lambda x: len(x))

# Passing the pivot table to heatmap for visualization
operating_human_bot.style.background_gradient(cmap ='Blues', axis=0)
# Out:
# <style type="text/css">
# #T_67f9d_row0_col0 {
#   background-color: #1a68ae;
#   color: #f1f1f1;
# }
# #T_67f9d_row0_col1, #T_67f9d_row26_col0 {
#   background-color: #3a8ac2;
#   color: #f1f1f1;
# }
# #T_67f9d_row1_col0 {
#   background-color: #084c95;
#   color: #f1f1f1;
# }
# #T_67f9d_row1_col1, #T_67f9d_row15_col0 {
#   background-color: #4a98c9;
#   color: #f1f1f1;
# }
# #T_67f9d_row2_col0 {
#   background-color: #8cc0dd;
#   color: #000000;
# }
# #T_67f9d_row2_col1 {
#   background-color: #92c4de;
#   color: #000000;
# }
# #T_67f9d_row3_col0, #T_67f9d_row27_col1 {
#   background-color: #66abd4;
#   color: #f1f1f1;
# }
# #T_67f9d_row3_col1, #T_67f9d_row7_col0 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_67f9d_row4_col0 {
#   background-color: #caddf0;
#   color: #000000;
# }
# #T_67f9d_row4_col1, #T_67f9d_row5_col1 {
#   background-color: #81badb;
#   color: #000000;
# }
# #T_67f9d_row5_col0 {
#   background-color: #57a0ce;
#   color: #f1f1f1;
# }
# #T_67f9d_row6_col0 {
#   background-color: #79b5d9;
#   color: #000000;
# }
# #T_67f9d_row6_col1, #T_67f9d_row30_col1 {
#   background-color: #1967ad;
#   color: #f1f1f1;
# }
# #T_67f9d_row7_col1 {
#   background-color: #99c7e0;
#   color: #000000;
# }
# #T_67f9d_row8_col0 {
#   background-color: #84bcdb;
#   color: #000000;
# }
# #T_67f9d_row8_col1 {
#   background-color: #2979b9;
#   color: #f1f1f1;
# }
# #T_67f9d_row9_col0 {
#   background-color: #1460a8;
#   color: #f1f1f1;
# }
# #T_67f9d_row9_col1 {
#   background-color: #084184;
#   color: #f1f1f1;
# }
# #T_67f9d_row10_col0, #T_67f9d_row29_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_67f9d_row10_col1, #T_67f9d_row18_col0 {
#   background-color: #5aa2cf;
#   color: #f1f1f1;
# }
# #T_67f9d_row11_col0 {
#   background-color: #4493c7;
#   color: #f1f1f1;
# }
# #T_67f9d_row11_col1 {
#   background-color: #3989c1;
#   color: #f1f1f1;
# }
# #T_67f9d_row12_col0 {
#   background-color: #2b7bba;
#   color: #f1f1f1;
# }
# #T_67f9d_row12_col1 {
#   background-color: #3585bf;
#   color: #f1f1f1;
# }
# #T_67f9d_row13_col0 {
#   background-color: #4b98ca;
#   color: #f1f1f1;
# }
# #T_67f9d_row13_col1, #T_67f9d_row17_col1 {
#   background-color: #d0e1f2;
#   color: #000000;
# }
# #T_67f9d_row14_col0 {
#   background-color: #58a1cf;
#   color: #f1f1f1;
# }
# #T_67f9d_row14_col1 {
#   background-color: #5ba3d0;
#   color: #f1f1f1;
# }
# #T_67f9d_row15_col1 {
#   background-color: #91c3de;
#   color: #000000;
# }
# #T_67f9d_row16_col0 {
#   background-color: #135fa7;
#   color: #f1f1f1;
# }
# #T_67f9d_row16_col1 {
#   background-color: #7ab6d9;
#   color: #000000;
# }
# #T_67f9d_row17_col0 {
#   background-color: #97c6df;
#   color: #000000;
# }
# #T_67f9d_row18_col1 {
#   background-color: #08468b;
#   color: #f1f1f1;
# }
# #T_67f9d_row19_col0 {
#   background-color: #8fc2de;
#   color: #000000;
# }
# #T_67f9d_row19_col1, #T_67f9d_row23_col0 {
#   background-color: #b9d6ea;
#   color: #000000;
# }
# #T_67f9d_row20_col0 {
#   background-color: #3282be;
#   color: #f1f1f1;
# }
# #T_67f9d_row20_col1 {
#   background-color: #c7dcef;
#   color: #000000;
# }
# #T_67f9d_row21_col0 {
#   background-color: #3d8dc4;
#   color: #f1f1f1;
# }
# #T_67f9d_row21_col1 {
#   background-color: #6fb0d7;
#   color: #f1f1f1;
# }
# #T_67f9d_row22_col0 {
#   background-color: #1561a9;
#   color: #f1f1f1;
# }
# #T_67f9d_row22_col1 {
#   background-color: #61a7d2;
#   color: #f1f1f1;
# }
# #T_67f9d_row23_col1 {
#   background-color: #125ea6;
#   color: #f1f1f1;
# }
# #T_67f9d_row24_col0 {
#   background-color: #56a0ce;
#   color: #f1f1f1;
# }
# #T_67f9d_row24_col1 {
#   background-color: #083674;
#   color: #f1f1f1;
# }
# #T_67f9d_row25_col0 {
#   background-color: #aed1e7;
#   color: #000000;
# }
# #T_67f9d_row25_col1 {
#   background-color: #e1edf8;
#   color: #000000;
# }
# #T_67f9d_row26_col1 {
#   background-color: #abd0e6;
#   color: #000000;
# }
# #T_67f9d_row27_col0 {
#   background-color: #1f6eb3;
#   color: #f1f1f1;
# }
# #T_67f9d_row28_col0, #T_67f9d_row35_col1 {
#   background-color: #95c5df;
#   color: #000000;
# }
# #T_67f9d_row28_col1 {
#   background-color: #5fa6d1;
#   color: #f1f1f1;
# }
# #T_67f9d_row29_col0 {
#   background-color: #084488;
#   color: #f1f1f1;
# }
# #T_67f9d_row30_col0 {
#   background-color: #3080bd;
#   color: #f1f1f1;
# }
# #T_67f9d_row31_col0 {
#   background-color: #539ecd;
#   color: #f1f1f1;
# }
# #T_67f9d_row31_col1 {
#   background-color: #7db8da;
#   color: #000000;
# }
# #T_67f9d_row32_col0 {
#   background-color: #084a91;
#   color: #f1f1f1;
# }
# #T_67f9d_row32_col1 {
#   background-color: #c9ddf0;
#   color: #000000;
# }
# #T_67f9d_row33_col0 {
#   background-color: #75b4d8;
#   color: #000000;
# }
# #T_67f9d_row33_col1 {
#   background-color: #08509b;
#   color: #f1f1f1;
# }
# #T_67f9d_row34_col0 {
#   background-color: #1764ab;
#   color: #f1f1f1;
# }
# #T_67f9d_row34_col1 {
#   background-color: #71b1d7;
#   color: #f1f1f1;
# }
# #T_67f9d_row35_col0 {
#   background-color: #2575b7;
#   color: #f1f1f1;
# }
# #T_67f9d_row36_col0 {
#   background-color: #deebf7;
#   color: #000000;
# }
# #T_67f9d_row36_col1 {
#   background-color: #1663aa;
#   color: #f1f1f1;
# }
# #T_67f9d_row37_col0 {
#   background-color: #1b69af;
#   color: #f1f1f1;
# }
# #T_67f9d_row37_col1 {
#   background-color: #2a7ab9;
#   color: #f1f1f1;
# }
# #T_67f9d_row38_col0 {
#   background-color: #6caed6;
#   color: #f1f1f1;
# }
# #T_67f9d_row38_col1 {
#   background-color: #e4eff9;
#   color: #000000;
# }
# #T_67f9d_row39_col0 {
#   background-color: #3888c1;
#   color: #f1f1f1;
# }
# #T_67f9d_row39_col1 {
#   background-color: #9ac8e0;
#   color: #000000;
# }
# </style>
# <table id="T_67f9d" class="dataframe">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Fraudulent Flag</th>
#       <th id="T_67f9d_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_67f9d_level0_col1" class="col_heading level0 col1" >1</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Operating System</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_67f9d_level0_row0" class="row_heading level0 row0" >AIX</th>
#       <td id="T_67f9d_row0_col0" class="data row0 col0" >75244</td>
#       <td id="T_67f9d_row0_col1" class="data row0 col1" >75136</td>
#     </tr>
#     <tr>
#       <th id="T_67f9d_level0_row1" class="row_heading level0 row1" >Android</th>
#       <td id="T_67f9d_row1_col0" class="data row1 col0" >75385</td>
#       <td id="T_67f9d_row1_col1" class="data row1 col1" >75077</td>
#     </tr>
#     <tr>
#       <th id="T_67f9d_level0_row2" class="row_heading level0 row2" >Android TV</th>
#       <td id="T_67f9d_row2_col0" class="data row2 col0" >74784</td>
#       <td id="T_67f9d_row2_col1" class="data row2 col1" >74862</td>
#     </tr>
#     <tr>
#       <th id="T_67f9d_level0_row3" class="row_heading level0 row3" >Android Wear</th>
#       <td id="T_67f9d_row3_col0" class="data row3 col0" >74905</td>
#       <td id="T_67f9d_row3_col1" class="data row3 col1" >75520</td>
#     </tr>
#     <tr>
#       <th id="T_67f9d_level0_row4" class="row_heading level0 row4" >Arch Linux</th>
#       <td id="T_67f9d_row4_col0" class="data row4 col0" >74543</td>
#       <td id="T_67f9d_row4_col1" class="data row4 col1" >74908</td>
#     </tr>
#     <tr>
#       <th id="T_67f9d_level0_row5" class="row_heading level0 row5" >BlackBerry</th>
#       <td id="T_67f9d_row5_col0" class="data row5 col0" >74963</td>
#       <td id="T_67f9d_row5_col1" class="data row5 col1" >74910</td>
#     </tr>
#     <tr>
#       <th id="T_67f9d_level0_row6" class="row_heading level0 row6" >CentOS</th>
#       <td id="T_67f9d_row6_col0" class="data row6 col0" >74844</td>
#       <td id="T_67f9d_row6_col1" class="data row6 col1" >75284</td>
#     </tr>
#     <tr>
#       <th id="T_67f9d_level0_row7" class="row_heading level0 row7" >Chrome OS</th>
#       <td id="T_67f9d_row7_col0" class="data row7 col0" >75521</td>
#       <td id="T_67f9d_row7_col1" class="data row7 col1" >74846</td>
#     </tr>
#     <tr>
#       <th id="T_67f9d_level0_row8" class="row_heading level0 row8" >Chromebook</th>
#       <td id="T_67f9d_row8_col0" class="data row8 col0" >74807</td>
#       <td id="T_67f9d_row8_col1" class="data row8 col1" >75210</td>
#     </tr>
#     <tr>
#       <th id="T_67f9d_level0_row9" class="row_heading level0 row9" >Debian</th>
#       <td id="T_67f9d_row9_col0" class="data row9 col0" >75283</td>
#       <td id="T_67f9d_row9_col1" class="data row9 col1" >75449</td>
#     </tr>
#     <tr>
#       <th id="T_

# %% [markdown]
# __Merchant Category__

# %%
merchant_df = data[['Merchant Category', 'Fraudulent Flag']]

# Creating a pivot table with Merchant category as index, outcome as columns and count of fraudulent as values
merchant_human_bot = merchant_df.pivot_table(values='Fraudulent Flag', index='Merchant Category', columns='Fraudulent Flag', fill_value=0,
                         aggfunc=lambda x: len(x))

# Passing the pivot table to heatmap for visualization
merchant_human_bot.style.background_gradient(cmap ='Blues', axis=0)
# Out:
# <style type="text/css">
# #T_da0e9_row0_col0 {
#   background-color: #63a8d3;
#   color: #f1f1f1;
# }
# #T_da0e9_row0_col1, #T_da0e9_row30_col1 {
#   background-color: #85bcdc;
#   color: #000000;
# }
# #T_da0e9_row1_col0 {
#   background-color: #b7d4ea;
#   color: #000000;
# }
# #T_da0e9_row1_col1 {
#   background-color: #1967ad;
#   color: #f1f1f1;
# }
# #T_da0e9_row2_col0 {
#   background-color: #61a7d2;
#   color: #f1f1f1;
# }
# #T_da0e9_row2_col1, #T_da0e9_row36_col0 {
#   background-color: #57a0ce;
#   color: #f1f1f1;
# }
# #T_da0e9_row3_col0 {
#   background-color: #a6cee4;
#   color: #000000;
# }
# #T_da0e9_row3_col1 {
#   background-color: #a8cee4;
#   color: #000000;
# }
# #T_da0e9_row4_col0, #T_da0e9_row34_col0 {
#   background-color: #4896c8;
#   color: #f1f1f1;
# }
# #T_da0e9_row4_col1 {
#   background-color: #e7f0fa;
#   color: #000000;
# }
# #T_da0e9_row5_col0, #T_da0e9_row8_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_da0e9_row5_col1 {
#   background-color: #b3d3e8;
#   color: #000000;
# }
# #T_da0e9_row6_col0 {
#   background-color: #2979b9;
#   color: #f1f1f1;
# }
# #T_da0e9_row6_col1, #T_da0e9_row15_col1 {
#   background-color: #3686c0;
#   color: #f1f1f1;
# }
# #T_da0e9_row7_col0 {
#   background-color: #3282be;
#   color: #f1f1f1;
# }
# #T_da0e9_row7_col1 {
#   background-color: #d0e2f2;
#   color: #000000;
# }
# #T_da0e9_row8_col0 {
#   background-color: #68acd5;
#   color: #f1f1f1;
# }
# #T_da0e9_row9_col0 {
#   background-color: #2474b7;
#   color: #f1f1f1;
# }
# #T_da0e9_row9_col1 {
#   background-color: #105ba4;
#   color: #f1f1f1;
# }
# #T_da0e9_row10_col0 {
#   background-color: #5fa6d1;
#   color: #f1f1f1;
# }
# #T_da0e9_row10_col1 {
#   background-color: #77b5d9;
#   color: #000000;
# }
# #T_da0e9_row11_col0 {
#   background-color: #3f8fc5;
#   color: #f1f1f1;
# }
# #T_da0e9_row11_col1 {
#   background-color: #09529d;
#   color: #f1f1f1;
# }
# #T_da0e9_row12_col0, #T_da0e9_row23_col1 {
#   background-color: #2c7cba;
#   color: #f1f1f1;
# }
# #T_da0e9_row12_col1, #T_da0e9_row17_col1, #T_da0e9_row20_col1 {
#   background-color: #64a9d3;
#   color: #f1f1f1;
# }
# #T_da0e9_row13_col0 {
#   background-color: #deebf7;
#   color: #000000;
# }
# #T_da0e9_row13_col1 {
#   background-color: #08458a;
#   color: #f1f1f1;
# }
# #T_da0e9_row14_col0 {
#   background-color: #3585bf;
#   color: #f1f1f1;
# }
# #T_da0e9_row14_col1 {
#   background-color: #97c6df;
#   color: #000000;
# }
# #T_da0e9_row15_col0 {
#   background-color: #b0d2e7;
#   color: #000000;
# }
# #T_da0e9_row16_col0 {
#   background-color: #5ba3d0;
#   color: #f1f1f1;
# }
# #T_da0e9_row16_col1 {
#   background-color: #7db8da;
#   color: #000000;
# }
# #T_da0e9_row17_col0 {
#   background-color: #3e8ec4;
#   color: #f1f1f1;
# }
# #T_da0e9_row18_col0, #T_da0e9_row20_col0 {
#   background-color: #79b5d9;
#   color: #000000;
# }
# #T_da0e9_row18_col1 {
#   background-color: #2a7ab9;
#   color: #f1f1f1;
# }
# #T_da0e9_row19_col0 {
#   background-color: #3787c0;
#   color: #f1f1f1;
# }
# #T_da0e9_row19_col1 {
#   background-color: #c2d9ee;
#   color: #000000;
# }
# #T_da0e9_row21_col0 {
#   background-color: #4a98c9;
#   color: #f1f1f1;
# }
# #T_da0e9_row21_col1 {
#   background-color: #08316d;
#   color: #f1f1f1;
# }
# #T_da0e9_row22_col0 {
#   background-color: #71b1d7;
#   color: #f1f1f1;
# }
# #T_da0e9_row22_col1 {
#   background-color: #c3daee;
#   color: #000000;
# }
# #T_da0e9_row23_col0 {
#   background-color: #1966ad;
#   color: #f1f1f1;
# }
# #T_da0e9_row24_col0 {
#   background-color: #4292c6;
#   color: #f1f1f1;
# }
# #T_da0e9_row24_col1 {
#   background-color: #539ecd;
#   color: #f1f1f1;
# }
# #T_da0e9_row25_col0 {
#   background-color: #8abfdd;
#   color: #000000;
# }
# #T_da0e9_row25_col1 {
#   background-color: #ddeaf7;
#   color: #000000;
# }
# #T_da0e9_row26_col0 {
#   background-color: #9cc9e1;
#   color: #000000;
# }
# #T_da0e9_row26_col1 {
#   background-color: #1d6cb1;
#   color: #f1f1f1;
# }
# #T_da0e9_row27_col0 {
#   background-color: #7fb9da;
#   color: #000000;
# }
# #T_da0e9_row27_col1, #T_da0e9_row31_col0 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_da0e9_row28_col0 {
#   background-color: #1562a9;
#   color: #f1f1f1;
# }
# #T_da0e9_row28_col1 {
#   background-color: #8fc2de;
#   color: #000000;
# }
# #T_da0e9_row29_col0 {
#   background-color: #08509b;
#   color: #f1f1f1;
# }
# #T_da0e9_row29_col1, #T_da0e9_row30_col0 {
#   background-color: #99c7e0;
#   color: #000000;
# }
# #T_da0e9_row31_col1 {
#   background-color: #74b3d8;
#   color: #000000;
# }
# #T_da0e9_row32_col0 {
#   background-color: #bcd7eb;
#   color: #000000;
# }
# #T_da0e9_row32_col1 {
#   background-color: #1c6ab0;
#   color: #f1f1f1;
# }
# #T_da0e9_row33_col0 {
#   background-color: #2b7bba;
#   color: #f1f1f1;
# }
# #T_da0e9_row33_col1 {
#   background-color: #115ca5;
#   color: #f1f1f1;
# }
# #T_da0e9_row34_col1 {
#   background-color: #afd1e7;
#   color: #000000;
# }
# #T_da0e9_row35_col0 {
#   background-color: #0c56a0;
#   color: #f1f1f1;
# }
# #T_da0e9_row35_col1 {
#   background-color: #84bcdb;
#   color: #000000;
# }
# #T_da0e9_row36_col1 {
#   background-color: #a0cbe2;
#   color: #000000;
# }
# #T_da0e9_row37_col0 {
#   background-color: #c8dcf0;
#   color: #000000;
# }
# #T_da0e9_row37_col1 {
#   background-color: #a4cce3;
#   color: #000000;
# }
# #T_da0e9_row38_col0 {
#   background-color: #82bbdb;
#   color: #000000;
# }
# #T_da0e9_row38_col1 {
#   background-color: #1663aa;
#   color: #f1f1f1;
# }
# #T_da0e9_row39_col0 {
#   background-color: #89bedc;
#   color: #000000;
# }
# #T_da0e9_row39_col1 {
#   background-color: #92c4de;
#   color: #000000;
# }
# </style>
# <table id="T_da0e9" class="dataframe">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Fraudulent Flag</th>
#       <th id="T_da0e9_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_da0e9_level0_col1" class="col_heading level0 col1" >1</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Merchant Category</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_da0e9_level0_row0" class="row_heading level0 row0" >Appliances</th>
#       <td id="T_da0e9_row0_col0" class="data row0 col0" >74975</td>
#       <td id="T_da0e9_row0_col1" class="data row0 col1" >74903</td>
#     </tr>
#     <tr>
#       <th id="T_da0e9_level0_row1" class="row_heading level0 row1" >Art & Collectibles</th>
#       <td id="T_da0e9_row1_col0" class="data row1 col0" >74620</td>
#       <td id="T_da0e9_row1_col1" class="data row1 col1" >75280</td>
#     </tr>
#     <tr>
#       <th id="T_da0e9_level0_row2" class="row_heading level0 row2" >Automotive</th>
#       <td id="T_da0e9_row2_col0" class="data row2 col0" >74980</td>
#       <td id="T_da0e9_row2_col1" class="data row2 col1" >75035</td>
#     </tr>
#     <tr>
#       <th id="T_da0e9_level0_row3" class="row_heading level0 row3" >Baby & Maternity</th>
#       <td id="T_da0e9_row3_col0" class="data row3 col0" >74701</td>
#       <td id="T_da0e9_row3_col1" class="data row3 col1" >74807</td>
#     </tr>
#     <tr>
#       <th id="T_da0e9_level0_row4" class="row_heading level0 row4" >Beauty & Cosmetics</th>
#       <td id="T_da0e9_row4_col0" class="data row4 col0" >75101</td>
#       <td id="T_da0e9_row4_col1" class="data row4 col1" >74526</td>
#     </tr>
#     <tr>
#       <th id="T_da0e9_level0_row5" class="row_heading level0 row5" >Books & Literature</th>
#       <td id="T_da0e9_row5_col0" class="data row5 col0" >75717</td>
#       <td id="T_da0e9_row5_col1" class="data row5 col1" >74766</td>
#     </tr>
#     <tr>
#       <th id="T_da0e9_level0_row6" class="row_heading level0 row6" >Charity & Nonprofit</th>
#       <td id="T_da0e9_row6_col0" class="data row6 col0" >75279</td>
#       <td id="T_da0e9_row6_col1" class="data row6 col1" >75155</td>
#     </tr>
#     <tr>
#       <th id="T_da0e9_level0_row7" class="row_heading level0 row7" >Clothing</th>
#       <td id="T_da0e9_row7_col0" class="data row7 col0" >75227</td>
#       <td id="T_da0e9_row7_col1" class="data row7 col1" >74647</td>
#     </tr>
#     <tr>
#       <th id="T_da0e9_level0_row8" class="row_heading level0 row8" >Education</th>
#       <td id="T_da0e9_row8_col0" class="data row8 col0" >74950</td>
#       <td id="T_da0e9_row8_col1" class="data row8 col1" >75508</td>
#     </tr>
#     <tr>
#       <th id="T_da0e9_level0_row9" class="row_heading level0 row9" >Electronics</th>
#       <td id="T_da0e9_row9_col0" class="data row9 col0" >75308</td>
#       <td id="T_da0e9_row9_col1" class="data row

# %% [markdown]
# __User Occupation__

# %%
occ_df = data[['User Occupation', 'Fraudulent Flag']]

# Creating a pivot table with occupation as index, outcome as columns and count of fraudulent as values
occ_human_bot = occ_df.pivot_table(values='Fraudulent Flag', index='User Occupation', columns='Fraudulent Flag', fill_value=0,
                         aggfunc=lambda x: len(x))

# Passing the pivot table to heatmap for visualization
occ_human_bot.style.background_gradient(cmap ='Blues', axis=0)
# Out:
# <style type="text/css">
# #T_c6d12_row0_col0, #T_c6d12_row21_col1, #T_c6d12_row24_col1 {
#   background-color: #5ca4d0;
#   color: #f1f1f1;
# }
# #T_c6d12_row0_col1, #T_c6d12_row19_col0 {
#   background-color: #2171b5;
#   color: #f1f1f1;
# }
# #T_c6d12_row1_col0 {
#   background-color: #d9e8f5;
#   color: #000000;
# }
# #T_c6d12_row1_col1 {
#   background-color: #e8f1fa;
#   color: #000000;
# }
# #T_c6d12_row2_col0 {
#   background-color: #3888c1;
#   color: #f1f1f1;
# }
# #T_c6d12_row2_col1 {
#   background-color: #f3f8fe;
#   color: #000000;
# }
# #T_c6d12_row3_col0 {
#   background-color: #4f9bcb;
#   color: #f1f1f1;
# }
# #T_c6d12_row3_col1 {
#   background-color: #6aaed6;
#   color: #f1f1f1;
# }
# #T_c6d12_row4_col0 {
#   background-color: #dbe9f6;
#   color: #000000;
# }
# #T_c6d12_row4_col1 {
#   background-color: #08458a;
#   color: #f1f1f1;
# }
# #T_c6d12_row5_col0, #T_c6d12_row20_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_c6d12_row5_col1, #T_c6d12_row7_col0 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_c6d12_row6_col0 {
#   background-color: #a0cbe2;
#   color: #000000;
# }
# #T_c6d12_row6_col1 {
#   background-color: #4a98c9;
#   color: #f1f1f1;
# }
# #T_c6d12_row7_col1 {
#   background-color: #69add5;
#   color: #f1f1f1;
# }
# #T_c6d12_row8_col0 {
#   background-color: #5ba3d0;
#   color: #f1f1f1;
# }
# #T_c6d12_row8_col1 {
#   background-color: #519ccc;
#   color: #f1f1f1;
# }
# #T_c6d12_row9_col0, #T_c6d12_row11_col1 {
#   background-color: #1764ab;
#   color: #f1f1f1;
# }
# #T_c6d12_row9_col1, #T_c6d12_row13_col1 {
#   background-color: #0a539e;
#   color: #f1f1f1;
# }
# #T_c6d12_row10_col0 {
#   background-color: #9cc9e1;
#   color: #000000;
# }
# #T_c6d12_row10_col1 {
#   background-color: #2777b8;
#   color: #f1f1f1;
# }
# #T_c6d12_row11_col0 {
#   background-color: #c1d9ed;
#   color: #000000;
# }
# #T_c6d12_row12_col0 {
#   background-color: #4090c5;
#   color: #f1f1f1;
# }
# #T_c6d12_row12_col1, #T_c6d12_row15_col0 {
#   background-color: #5fa6d1;
#   color: #f1f1f1;
# }
# #T_c6d12_row13_col0 {
#   background-color: #d3e4f3;
#   color: #000000;
# }
# #T_c6d12_row14_col0 {
#   background-color: #4997c9;
#   color: #f1f1f1;
# }
# #T_c6d12_row14_col1 {
#   background-color: #083674;
#   color: #f1f1f1;
# }
# #T_c6d12_row15_col1 {
#   background-color: #2676b8;
#   color: #f1f1f1;
# }
# #T_c6d12_row16_col0 {
#   background-color: #91c3de;
#   color: #000000;
# }
# #T_c6d12_row16_col1 {
#   background-color: #0b559f;
#   color: #f1f1f1;
# }
# #T_c6d12_row17_col0 {
#   background-color: #7ab6d9;
#   color: #000000;
# }
# #T_c6d12_row17_col1 {
#   background-color: #d2e3f3;
#   color: #000000;
# }
# #T_c6d12_row18_col0 {
#   background-color: #2f7fbc;
#   color: #f1f1f1;
# }
# #T_c6d12_row18_col1 {
#   background-color: #4292c6;
#   color: #f1f1f1;
# }
# #T_c6d12_row19_col1 {
#   background-color: #1460a8;
#   color: #f1f1f1;
# }
# #T_c6d12_row20_col0 {
#   background-color: #539ecd;
#   color: #f1f1f1;
# }
# #T_c6d12_row21_col0 {
#   background-color: #d7e6f5;
#   color: #000000;
# }
# #T_c6d12_row22_col0 {
#   background-color: #206fb4;
#   color: #f1f1f1;
# }
# #T_c6d12_row22_col1 {
#   background-color: #083b7c;
#   color: #f1f1f1;
# }
# #T_c6d12_row23_col0 {
#   background-color: #b8d5ea;
#   color: #000000;
# }
# #T_c6d12_row23_col1 {
#   background-color: #87bddc;
#   color: #000000;
# }
# #T_c6d12_row24_col0 {
#   background-color: #aacfe5;
#   color: #000000;
# }
# #T_c6d12_row25_col0 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_c6d12_row25_col1 {
#   background-color: #79b5d9;
#   color: #000000;
# }
# </style>
# <table id="T_c6d12" class="dataframe">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Fraudulent Flag</th>
#       <th id="T_c6d12_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_c6d12_level0_col1" class="col_heading level0 col1" >1</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >User Occupation</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c6d12_level0_row0" class="row_heading level0 row0" >Accountant</th>
#       <td id="T_c6d12_row0_col0" class="data row0 col0" >115493</td>
#       <td id="T_c6d12_row0_col1" class="data row0 col1" >115537</td>
#     </tr>
#     <tr>
#       <th id="T_c6d12_level0_row1" class="row_heading level0 row1" >Architect</th>
#       <td id="T_c6d12_row1_col0" class="data row1 col0" >115031</td>
#       <td id="T_c6d12_row1_col1" class="data row1 col1" >114775</td>
#     </tr>
#     <tr>
#       <th id="T_c6d12_level0_row2" class="row_heading level0 row2" >Artist</th>
#       <td id="T_c6d12_row2_col0" class="data row2 col0" >115628</td>
#       <td id="T_c6d12_row2_col1" class="data row2 col1" >114713</td>
#     </tr>
#     <tr>
#       <th id="T_c6d12_level0_row3" class="row_heading level0 row3" >Biologist</th>
#       <td id="T_c6d12_row3_col0" class="data row3 col0" >115537</td>
#       <td id="T_c6d12_row3_col1" class="data row3 col1" >115259</td>
#     </tr>
#     <tr>
#       <th id="T_c6d12_level0_row4" class="row_heading level0 row4" >Chef</th>
#       <td id="T_c6d12_row4_col0" class="data row4 col0" >115021</td>
#       <td id="T_c6d12_row4_col1" class="data row4 col1" >115730</td>
#     </tr>
#     <tr>
#       <th id="T_c6d12_level0_row5" class="row_heading level0 row5" >Chemist</th>
#       <td id="T_c6d12_row5_col0" class="data row5 col0" >116023</td>
#       <td id="T_c6d12_row5_col1" class="data row5 col1" >114688</td>
#     </tr>
#     <tr>
#       <th id="T_c6d12_level0_row6" class="row_heading level0 row6" >Counselor</th>
#       <td id="T_c6d12_row6_col0" class="data row6 col0" >115287</td>
#       <td id="T_c6d12_row6_col1" class="data row6 col1" >115367</td>
#     </tr>
#     <tr>
#       <th id="T_c6d12_level0_row7" class="row_heading level0 row7" >Doctor</th>
#       <td id="T_c6d12_row7_col0" class="data row7 col0" >114854</td>
#       <td id="T_c6d12_row7_col1" class="data row7 col1" >115263</td>
#     </tr>
#     <tr>
#       <th id="T_c6d12_level0_row8" class="row_heading level0 row8" >Electrician</th>
#       <td id="T_c6d12_row8_col0" class="data row8 col0" >115495</td>
#       <td id="T_c6d12_row8_col1" class="data row8 col1" >115345</td>
#     </tr>
#     <tr>
#       <th id="T_c6d12_level0_row9" class="row_heading level0 row9" >Engineer</th>
#       <td id="T_c6d12_row9_col0" class="data row9 col0" >115789</td>
#       <td id="T_c6d12_row9_col1" class="data row9 col1" >115668</td>
#     </tr>
#     <tr>
#       <th id="T_c6d12_level0_row10" class="row_heading level0 row10" >Event Planner</th>
#       <td id="T_c6d12_row10_col0" class="data row10 col0" >115297</td>
#       <td id="T_c6d12_row10_col1" class="data row10 col1" >115510</td>
#     </tr>
#     <tr>
#       <th id="T_c6d12_level0_row11" class="row_heading level0 row11" >Fashion Designer</th>
#       <td id="T_c6d12_row11_col0" class="data row11 col0" >115167</td>
#       <td id="T_c6d12_row11_col1" class="data row11 col1" >115596</td>
#     </tr>
#     <tr>
#       <th id="T_c6d12_level0_row12" class="row_heading level0 row12" >Firefighter</th>
#       <td id="T_c6d12_row12_col0" class="data row12 col0" >115592</td>
#       <td id="T_c6d12_row12_col1" class="data row12 col1" >115297</td>
#     </tr>
#     <tr>
#       <th id="T_c6d12_level0_row13" class="row_heading level0 row13" >Geologist</th>
#       <td id="T_c6d12_row13_col0" class="data row13 col0" >115066</td>
#       <td id="T_c6d12_row13_col1" class="data row13 col1" >115670</td>
#     </tr>
#     <tr>
#       <th id="T_c6d12_level0_row14" class="row_heading level0 row14" >Lawyer</th>
#       <td id="T_c6d12_row14_col0" class="data row14 col0" >115560</td>
#       <td id="T_c6d12_row14_col1" class="data row14 col1" >115793</td>
#     </tr>
#     <tr>
#       <th id="T_c6d12_level0_row15" class="row_heading level0 row15" >Mathematician</th>
#       <td id="T_c6d12_row15_col0" class="data row15 col0" >115484</td>
#       <td id="T_c6d12_row15_col1" class="data row15 col1" >115514</td>
#     </tr>
#     <tr>
#       <th id="T_c6d12_level0_row16" class="row_heading level0 row16" >Nurse</th>
#       <td id="T_c6d12_row16_col0" class="data row16 col0" >115329</td>
#       <td id="T_c6d12_row16_col1" class="data row16 col1" >115662</td>
#     </tr>
#     <tr>
#       <th id="T_c6d12_level0_row17" class="row_heading level0 row17" >Physicist</th>
#       <td id="T_c6d12_

# %% [markdown]
# __User Gender__

# %%
gen_df = data[['User Gender', 'Fraudulent Flag']]

# Creating a pivot table with gender as index, fraudulent flag as columns and count of fraudulent as values
gen_human_bot = gen_df.pivot_table(values='Fraudulent Flag', index='User Gender', columns='Fraudulent Flag', fill_value=0,
                         aggfunc=lambda x: len(x))

# Passing the pivot table to heatmap for visualization
gen_human_bot.style.background_gradient(cmap ='Blues', axis=0)
# Out:
# <style type="text/css">
# #T_3b0bd_row0_col0, #T_3b0bd_row1_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_3b0bd_row0_col1 {
#   background-color: #77b5d9;
#   color: #000000;
# }
# #T_3b0bd_row1_col0, #T_3b0bd_row3_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_3b0bd_row2_col0 {
#   background-color: #bed8ec;
#   color: #000000;
# }
# #T_3b0bd_row2_col1 {
#   background-color: #4594c7;
#   color: #f1f1f1;
# }
# #T_3b0bd_row3_col0 {
#   background-color: #1e6db2;
#   color: #f1f1f1;
# }
# #T_3b0bd_row4_col0 {
#   background-color: #105ba4;
#   color: #f1f1f1;
# }
# #T_3b0bd_row4_col1 {
#   background-color: #1663aa;
#   color: #f1f1f1;
# }
# #T_3b0bd_row5_col0 {
#   background-color: #a5cde3;
#   color: #000000;
# }
# #T_3b0bd_row5_col1 {
#   background-color: #9cc9e1;
#   color: #000000;
# }
# #T_3b0bd_row6_col0 {
#   background-color: #1f6eb3;
#   color: #f1f1f1;
# }
# #T_3b0bd_row6_col1 {
#   background-color: #9fcae1;
#   color: #000000;
# }
# </style>
# <table id="T_3b0bd" class="dataframe">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Fraudulent Flag</th>
#       <th id="T_3b0bd_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_3b0bd_level0_col1" class="col_heading level0 col1" >1</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >User Gender</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3b0bd_level0_row0" class="row_heading level0 row0" >Agender</th>
#       <td id="T_3b0bd_row0_col0" class="data row0 col0" >427683</td>
#       <td id="T_3b0bd_row0_col1" class="data row0 col1" >428468</td>
#     </tr>
#     <tr>
#       <th id="T_3b0bd_level0_row1" class="row_heading level0 row1" >Female</th>
#       <td id="T_3b0bd_row1_col0" class="data row1 col0" >429264</td>
#       <td id="T_3b0bd_row1_col1" class="data row1 col1" >427641</td>
#     </tr>
#     <tr>
#       <th id="T_3b0bd_level0_row2" class="row_heading level0 row2" >Genderqueer</th>
#       <td id="T_3b0bd_row2_col0" class="data row2 col0" >428121</td>
#       <td id="T_3b0bd_row2_col1" class="data row2 col1" >428727</td>
#     </tr>
#     <tr>
#       <th id="T_3b0bd_level0_row3" class="row_heading level0 row3" >Male</th>
#       <td id="T_3b0bd_row3_col0" class="data row3 col0" >428893</td>
#       <td id="T_3b0bd_row3_col1" class="data row3 col1" >429405</td>
#     </tr>
#     <tr>
#       <th id="T_3b0bd_level0_row4" class="row_heading level0 row4" >Non-Binary</th>
#       <td id="T_3b0bd_row4_col0" class="data row4 col0" >429004</td>
#       <td id="T_3b0bd_row4_col1" class="data row4 col1" >429056</td>
#     </tr>
#     <tr>
#       <th id="T_3b0bd_level0_row5" class="row_heading level0 row5" >Other</th>
#       <td id="T_3b0bd_row5_col0" class="data row5 col0" >428243</td>
#       <td id="T_3b0bd_row5_col1" class="data row5 col1" >428311</td>
#     </tr>
#     <tr>
#       <th id="T_3b0bd_level0_row6" class="row_heading level0 row6" >Prefer Not to Say</th>
#       <td id="T_3b0bd_row6_col0" class="data row6 col0" >428886</td>
#       <td id="T_3b0bd_row6_col1" class="data row6 col1" >428298</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# __Transaction time of day__

# %%
tran_df = data[['Transaction Time of Day', 'Fraudulent Flag']]

# Creating a pivot table with gender as index, fraudulent flag as columns and count of fraudulent as values
tran_human_bot = tran_df.pivot_table(values='Fraudulent Flag', index='Transaction Time of Day', columns='Fraudulent Flag', fill_value=0,
                         aggfunc=lambda x: len(x))

# Passing the pivot table to heatmap for visualization
tran_human_bot.style.background_gradient(cmap ='Blues', axis=0)
# Out:
# <style type="text/css">
# #T_54807_row0_col0 {
#   background-color: #f5fafe;
#   color: #000000;
# }
# #T_54807_row0_col1, #T_54807_row1_col0 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_54807_row1_col1, #T_54807_row2_col0 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_54807_row2_col1 {
#   background-color: #4e9acb;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_54807" class="dataframe">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Fraudulent Flag</th>
#       <th id="T_54807_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_54807_level0_col1" class="col_heading level0 col1" >1</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Transaction Time of Day</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_54807_level0_row0" class="row_heading level0 row0" >Daytime</th>
#       <td id="T_54807_row0_col0" class="data row0 col0" >999496</td>
#       <td id="T_54807_row0_col1" class="data row0 col1" >999099</td>
#     </tr>
#     <tr>
#       <th id="T_54807_level0_row1" class="row_heading level0 row1" >Evening</th>
#       <td id="T_54807_row1_col0" class="data row1 col0" >999482</td>
#       <td id="T_54807_row1_col1" class="data row1 col1" >1000743</td>
#     </tr>
#     <tr>
#       <th id="T_54807_level0_row2" class="row_heading level0 row2" >Nighttime</th>
#       <td id="T_54807_row2_col0" class="data row2 col0" >1001116</td>
#       <td id="T_54807_row2_col1" class="data row2 col1" >1000064</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# __User's device location__

# %%
loc_df = data[["User's Device Location", 'Fraudulent Flag']]

# Creating a pivot table with device location as index, fraudulent flag as columns and count of fraudulent as values
loc_human_bot = loc_df.pivot_table(values='Fraudulent Flag', index="User's Device Location", columns='Fraudulent Flag', fill_value=0,
                         aggfunc=lambda x: len(x))

# Passing the pivot table to heatmap for visualization
loc_human_bot.style.background_gradient(cmap ='Blues', axis=0)
# Out:
# <style type="text/css">
# #T_df448_row0_col0, #T_df448_row18_col0 {
#   background-color: #3383be;
#   color: #f1f1f1;
# }
# #T_df448_row0_col1 {
#   background-color: #dae8f6;
#   color: #000000;
# }
# #T_df448_row1_col0 {
#   background-color: #aed1e7;
#   color: #000000;
# }
# #T_df448_row1_col1, #T_df448_row25_col1 {
#   background-color: #cee0f2;
#   color: #000000;
# }
# #T_df448_row2_col0 {
#   background-color: #bcd7eb;
#   color: #000000;
# }
# #T_df448_row2_col1 {
#   background-color: #8cc0dd;
#   color: #000000;
# }
# #T_df448_row3_col0, #T_df448_row14_col0 {
#   background-color: #add0e6;
#   color: #000000;
# }
# #T_df448_row3_col1 {
#   background-color: #dfebf7;
#   color: #000000;
# }
# #T_df448_row4_col0 {
#   background-color: #bed8ec;
#   color: #000000;
# }
# #T_df448_row4_col1 {
#   background-color: #2373b6;
#   color: #f1f1f1;
# }
# #T_df448_row5_col0, #T_df448_row36_col0 {
#   background-color: #539ecd;
#   color: #f1f1f1;
# }
# #T_df448_row5_col1, #T_df448_row24_col0 {
#   background-color: #4191c6;
#   color: #f1f1f1;
# }
# #T_df448_row6_col0 {
#   background-color: #2979b9;
#   color: #f1f1f1;
# }
# #T_df448_row6_col1, #T_df448_row33_col0, #T_df448_row37_col0 {
#   background-color: #a1cbe2;
#   color: #000000;
# }
# #T_df448_row7_col0 {
#   background-color: #d9e8f5;
#   color: #000000;
# }
# #T_df448_row7_col1, #T_df448_row8_col0 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_df448_row8_col1 {
#   background-color: #c4daee;
#   color: #000000;
# }
# #T_df448_row9_col0 {
#   background-color: #1e6db2;
#   color: #f1f1f1;
# }
# #T_df448_row9_col1 {
#   background-color: #0d57a1;
#   color: #f1f1f1;
# }
# #T_df448_row10_col0 {
#   background-color: #2d7dbb;
#   color: #f1f1f1;
# }
# #T_df448_row10_col1, #T_df448_row20_col1 {
#   background-color: #7cb7da;
#   color: #000000;
# }
# #T_df448_row11_col0, #T_df448_row35_col0 {
#   background-color: #2171b5;
#   color: #f1f1f1;
# }
# #T_df448_row11_col1 {
#   background-color: #c2d9ee;
#   color: #000000;
# }
# #T_df448_row12_col0 {
#   background-color: #1c6ab0;
#   color: #f1f1f1;
# }
# #T_df448_row12_col1 {
#   background-color: #e8f1fa;
#   color: #000000;
# }
# #T_df448_row13_col0 {
#   background-color: #3a8ac2;
#   color: #f1f1f1;
# }
# #T_df448_row13_col1 {
#   background-color: #81badb;
#   color: #000000;
# }
# #T_df448_row14_col1 {
#   background-color: #ecf4fb;
#   color: #000000;
# }
# #T_df448_row15_col0, #T_df448_row19_col0 {
#   background-color: #083e81;
#   color: #f1f1f1;
# }
# #T_df448_row15_col1 {
#   background-color: #2575b7;
#   color: #f1f1f1;
# }
# #T_df448_row16_col0 {
#   background-color: #7db8da;
#   color: #000000;
# }
# #T_df448_row16_col1 {
#   background-color: #d2e3f3;
#   color: #000000;
# }
# #T_df448_row17_col0 {
#   background-color: #115ca5;
#   color: #f1f1f1;
# }
# #T_df448_row17_col1, #T_df448_row33_col1 {
#   background-color: #2e7ebc;
#   color: #f1f1f1;
# }
# #T_df448_row18_col1 {
#   background-color: #bad6eb;
#   color: #000000;
# }
# #T_df448_row19_col1 {
#   background-color: #a5cde3;
#   color: #000000;
# }
# #T_df448_row20_col0 {
#   background-color: #6aaed6;
#   color: #f1f1f1;
# }
# #T_df448_row21_col0 {
#   background-color: #084990;
#   color: #f1f1f1;
# }
# #T_df448_row21_col1, #T_df448_row35_col1 {
#   background-color: #7fb9da;
#   color: #000000;
# }
# #T_df448_row22_col0 {
#   background-color: #519ccc;
#   color: #f1f1f1;
# }
# #T_df448_row22_col1 {
#   background-color: #0a539e;
#   color: #f1f1f1;
# }
# #T_df448_row23_col0, #T_df448_row26_col0 {
#   background-color: #4896c8;
#   color: #f1f1f1;
# }
# #T_df448_row23_col1 {
#   background-color: #5aa2cf;
#   color: #f1f1f1;
# }
# #T_df448_row24_col1 {
#   background-color: #9cc9e1;
#   color: #000000;
# }
# #T_df448_row25_col0 {
#   background-color: #60a7d2;
#   color: #f1f1f1;
# }
# #T_df448_row26_col1 {
#   background-color: #c6dbef;
#   color: #000000;
# }
# #T_df448_row27_col0 {
#   background-color: #3585bf;
#   color: #f1f1f1;
# }
# #T_df448_row27_col1 {
#   background-color: #aacfe5;
#   color: #000000;
# }
# #T_df448_row28_col0 {
#   background-color: #1b69af;
#   color: #f1f1f1;
# }
# #T_df448_row28_col1 {
#   background-color: #3787c0;
#   color: #f1f1f1;
# }
# #T_df448_row29_col0 {
#   background-color: #5da5d1;
#   color: #f1f1f1;
# }
# #T_df448_row29_col1, #T_df448_row38_col0 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_df448_row30_col0 {
#   background-color: #3989c1;
#   color: #f1f1f1;
# }
# #T_df448_row30_col1 {
#   background-color: #2272b6;
#   color: #f1f1f1;
# }
# #T_df448_row31_col0 {
#   background-color: #2c7cba;
#   color: #f1f1f1;
# }
# #T_df448_row31_col1 {
#   background-color: #a3cce3;
#   color: #000000;
# }
# #T_df448_row32_col0 {
#   background-color: #0e59a2;
#   color: #f1f1f1;
# }
# #T_df448_row32_col1 {
#   background-color: #4695c8;
#   color: #f1f1f1;
# }
# #T_df448_row34_col0 {
#   background-color: #74b3d8;
#   color: #000000;
# }
# #T_df448_row34_col1 {
#   background-color: #4a98c9;
#   color: #f1f1f1;
# }
# #T_df448_row36_col1 {
#   background-color: #94c4df;
#   color: #000000;
# }
# #T_df448_row37_col1 {
#   background-color: #f4f9fe;
#   color: #000000;
# }
# #T_df448_row38_col1 {
#   background-color: #2b7bba;
#   color: #f1f1f1;
# }
# #T_df448_row39_col0 {
#   background-color: #66abd4;
#   color: #f1f1f1;
# }
# #T_df448_row39_col1 {
#   background-color: #92c4de;
#   color: #000000;
# }
# </style>
# <table id="T_df448" class="dataframe">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Fraudulent Flag</th>
#       <th id="T_df448_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_df448_level0_col1" class="col_heading level0 col1" >1</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >User's Device Location</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_df448_level0_row0" class="row_heading level0 row0" >Argentina</th>
#       <td id="T_df448_row0_col0" class="data row0 col0" >75121</td>
#       <td id="T_df448_row0_col1" class="data row0 col1" >74697</td>
#     </tr>
#     <tr>
#       <th id="T_df448_level0_row1" class="row_heading level0 row1" >Australia</th>
#       <td id="T_df448_row1_col0" class="data row1 col0" >74630</td>
#       <td id="T_df448_row1_col1" class="data row1 col1" >74762</td>
#     </tr>
#     <tr>
#       <th id="T_df448_level0_row2" class="row_heading level0 row2" >Austria</th>
#       <td id="T_df448_row2_col0" class="data row2 col0" >74574</td>
#       <td id="T_df448_row2_col1" class="data row2 col1" >74979</td>
#     </tr>
#     <tr>
#       <th id="T_df448_level0_row3" class="row_heading level0 row3" >Belgium</th>
#       <td id="T_df448_row3_col0" class="data row3 col0" >74635</td>
#       <td id="T_df448_row3_col1" class="data row3 col1" >74675</td>
#     </tr>
#     <tr>
#       <th id="T_df448_level0_row4" class="row_heading level0 row4" >Brazil</th>
#       <td id="T_df448_row4_col0" class="data row4 col0" >74559</td>
#       <td id="T_df448_row4_col1" class="data row4 col1" >75312</td>
#     </tr>
#     <tr>
#       <th id="T_df448_level0_row5" class="row_heading level0 row5" >Canada</th>
#       <td id="T_df448_row5_col0" class="data row5 col0" >74973</td>
#       <td id="T_df448_row5_col1" class="data row5 col1" >75192</td>
#     </tr>
#     <tr>
#       <th id="T_df448_level0_row6" class="row_heading level0 row6" >China</th>
#       <td id="T_df448_row6_col0" class="data row6 col0" >75178</td>
#       <td id="T_df448_row6_col1" class="data row6 col1" >74922</td>
#     </tr>
#     <tr>
#       <th id="T_df448_level0_row7" class="row_heading level0 row7" >Egypt</th>
#       <td id="T_df448_row7_col0" class="data row7 col0" >74387</td>
#       <td id="T_df448_row7_col1" class="data row7 col1" >74547</td>
#     </tr>
#     <tr>
#       <th id="T_df448_level0_row8" class="row_heading level0 row8" >France</th>
#       <td id="T_df448_row8_col0" class="data row8 col0" >74180</td>
#       <td id="T_df448_row8_col1" class="data row8 col1" >74810</td>
#     </tr>
#     <tr>
#       <th id="T_df448_level0_row9" class="row_heading level0 row9" >Germany</th>
#       <td id="T_df448_row9_col0" class="data row9 col0" >75235</td>
#       <td id="T_df448_row9_col1" class="data row9 col1" >75424</td>
#     </tr>
#     <tr>
#       <th id="T_df448_level0_row10" class="row_heading level0 row10" >Greece</th>
#       <td id="T_df448_row10_col0" class="data row10 col0" >75154</td>
#       <td id="T_df448_row10_col1" class="data row10 col1" >75021</td>

# %% [markdown]
# __Transaction Currency__

# %%
curr_df = data[["Transaction Currency", 'Fraudulent Flag']]

# Creating a pivot table with currency as index, fraudulent flag as columns and count of fraudulent as values
curr_human_bot = curr_df.pivot_table(values='Fraudulent Flag', index="Transaction Currency", columns='Fraudulent Flag', fill_value=0,
                         aggfunc=lambda x: len(x))

# Passing the pivot table to heatmap for visualization
curr_human_bot.style.background_gradient(cmap ='Blues', axis=0)
# Out:
# <style type="text/css">
# #T_692c7_row0_col0, #T_692c7_row32_col1 {
#   background-color: #4b98ca;
#   color: #f1f1f1;
# }
# #T_692c7_row0_col1 {
#   background-color: #b2d2e8;
#   color: #000000;
# }
# #T_692c7_row1_col0 {
#   background-color: #c3daee;
#   color: #000000;
# }
# #T_692c7_row1_col1, #T_692c7_row39_col1 {
#   background-color: #206fb4;
#   color: #f1f1f1;
# }
# #T_692c7_row2_col0 {
#   background-color: #519ccc;
#   color: #f1f1f1;
# }
# #T_692c7_row2_col1 {
#   background-color: #2777b8;
#   color: #f1f1f1;
# }
# #T_692c7_row3_col0 {
#   background-color: #60a7d2;
#   color: #f1f1f1;
# }
# #T_692c7_row3_col1, #T_692c7_row19_col0 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_692c7_row4_col0 {
#   background-color: #caddf0;
#   color: #000000;
# }
# #T_692c7_row4_col1 {
#   background-color: #8fc2de;
#   color: #000000;
# }
# #T_692c7_row5_col0 {
#   background-color: #8cc0dd;
#   color: #000000;
# }
# #T_692c7_row5_col1, #T_692c7_row11_col1 {
#   background-color: #68acd5;
#   color: #f1f1f1;
# }
# #T_692c7_row6_col0 {
#   background-color: #66abd4;
#   color: #f1f1f1;
# }
# #T_692c7_row6_col1 {
#   background-color: #083e81;
#   color: #f1f1f1;
# }
# #T_692c7_row7_col0, #T_692c7_row37_col0 {
#   background-color: #56a0ce;
#   color: #f1f1f1;
# }
# #T_692c7_row7_col1 {
#   background-color: #75b4d8;
#   color: #000000;
# }
# #T_692c7_row8_col0 {
#   background-color: #1562a9;
#   color: #f1f1f1;
# }
# #T_692c7_row8_col1, #T_692c7_row9_col0 {
#   background-color: #7db8da;
#   color: #000000;
# }
# #T_692c7_row9_col1 {
#   background-color: #083c7d;
#   color: #f1f1f1;
# }
# #T_692c7_row10_col0 {
#   background-color: #dae8f6;
#   color: #000000;
# }
# #T_692c7_row10_col1, #T_692c7_row23_col0 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_692c7_row11_col0 {
#   background-color: #08316d;
#   color: #f1f1f1;
# }
# #T_692c7_row12_col0, #T_692c7_row31_col0 {
#   background-color: #d3e3f3;
#   color: #000000;
# }
# #T_692c7_row12_col1 {
#   background-color: #3888c1;
#   color: #f1f1f1;
# }
# #T_692c7_row13_col0 {
#   background-color: #dfebf7;
#   color: #000000;
# }
# #T_692c7_row13_col1, #T_692c7_row25_col0 {
#   background-color: #57a0ce;
#   color: #f1f1f1;
# }
# #T_692c7_row14_col0, #T_692c7_row21_col0 {
#   background-color: #65aad4;
#   color: #f1f1f1;
# }
# #T_692c7_row14_col1, #T_692c7_row18_col0 {
#   background-color: #105ba4;
#   color: #f1f1f1;
# }
# #T_692c7_row15_col0 {
#   background-color: #b9d6ea;
#   color: #000000;
# }
# #T_692c7_row15_col1 {
#   background-color: #8dc1dd;
#   color: #000000;
# }
# #T_692c7_row16_col0 {
#   background-color: #a8cee4;
#   color: #000000;
# }
# #T_692c7_row16_col1, #T_692c7_row24_col0 {
#   background-color: #a5cde3;
#   color: #000000;
# }
# #T_692c7_row17_col0, #T_692c7_row39_col0 {
#   background-color: #08509b;
#   color: #f1f1f1;
# }
# #T_692c7_row17_col1, #T_692c7_row25_col1, #T_692c7_row38_col0 {
#   background-color: #c1d9ed;
#   color: #000000;
# }
# #T_692c7_row18_col1 {
#   background-color: #a3cce3;
#   color: #000000;
# }
# #T_692c7_row19_col1 {
#   background-color: #5aa2cf;
#   color: #f1f1f1;
# }
# #T_692c7_row20_col0 {
#   background-color: #add0e6;
#   color: #000000;
# }
# #T_692c7_row20_col1 {
#   background-color: #c4daee;
#   color: #000000;
# }
# #T_692c7_row21_col1, #T_692c7_row26_col1, #T_692c7_row32_col0 {
#   background-color: #6fb0d7;
#   color: #f1f1f1;
# }
# #T_692c7_row22_col0 {
#   background-color: #084b93;
#   color: #f1f1f1;
# }
# #T_692c7_row22_col1 {
#   background-color: #2676b8;
#   color: #f1f1f1;
# }
# #T_692c7_row23_col1, #T_692c7_row27_col1 {
#   background-color: #529dcc;
#   color: #f1f1f1;
# }
# #T_692c7_row24_col1 {
#   background-color: #7ab6d9;
#   color: #000000;
# }
# #T_692c7_row26_col0 {
#   background-color: #cddff1;
#   color: #000000;
# }
# #T_692c7_row27_col0 {
#   background-color: #e6f0f9;
#   color: #000000;
# }
# #T_692c7_row28_col0 {
#   background-color: #d9e7f5;
#   color: #000000;
# }
# #T_692c7_row28_col1, #T_692c7_row36_col0 {
#   background-color: #6aaed6;
#   color: #f1f1f1;
# }
# #T_692c7_row29_col0 {
#   background-color: #3787c0;
#   color: #f1f1f1;
# }
# #T_692c7_row29_col1 {
#   background-color: #3484bf;
#   color: #f1f1f1;
# }
# #T_692c7_row30_col0 {
#   background-color: #c8dcf0;
#   color: #000000;
# }
# #T_692c7_row30_col1 {
#   background-color: #7fb9da;
#   color: #000000;
# }
# #T_692c7_row31_col1 {
#   background-color: #1764ab;
#   color: #f1f1f1;
# }
# #T_692c7_row33_col0 {
#   background-color: #2575b7;
#   color: #f1f1f1;
# }
# #T_692c7_row33_col1 {
#   background-color: #125da6;
#   color: #f1f1f1;
# }
# #T_692c7_row34_col0 {
#   background-color: #a1cbe2;
#   color: #000000;
# }
# #T_692c7_row34_col1 {
#   background-color: #cfe1f2;
#   color: #000000;
# }
# #T_692c7_row35_col0 {
#   background-color: #aed1e7;
#   color: #000000;
# }
# #T_692c7_row35_col1 {
#   background-color: #5da5d1;
#   color: #f1f1f1;
# }
# #T_692c7_row36_col1 {
#   background-color: #2d7dbb;
#   color: #f1f1f1;
# }
# #T_692c7_row37_col1 {
#   background-color: #0e59a2;
#   color: #f1f1f1;
# }
# #T_692c7_row38_col1 {
#   background-color: #6caed6;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_692c7" class="dataframe">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Fraudulent Flag</th>
#       <th id="T_692c7_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_692c7_level0_col1" class="col_heading level0 col1" >1</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Transaction Currency</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_692c7_level0_row0" class="row_heading level0 row0" >AED</th>
#       <td id="T_692c7_row0_col0" class="data row0 col0" >75148</td>
#       <td id="T_692c7_row0_col1" class="data row0 col1" >74672</td>
#     </tr>
#     <tr>
#       <th id="T_692c7_level0_row1" class="row_heading level0 row1" >ARS</th>
#       <td id="T_692c7_row1_col0" class="data row1 col0" >74772</td>
#       <td id="T_692c7_row1_col1" class="data row1 col1" >75264</td>
#     </tr>
#     <tr>
#       <th id="T_692c7_level0_row2" class="row_heading level0 row2" >AUD</th>
#       <td id="T_692c7_row2_col0" class="data row2 col0" >75132</td>
#       <td id="T_692c7_row2_col1" class="data row2 col1" >75221</td>
#     </tr>
#     <tr>
#       <th id="T_692c7_level0_row3" class="row_heading level0 row3" >BRL</th>
#       <td id="T_692c7_row3_col0" class="data row3 col0" >75078</td>
#       <td id="T_692c7_row3_col1" class="data row3 col1" >74245</td>
#     </tr>
#     <tr>
#       <th id="T_692c7_level0_row4" class="row_heading level0 row4" >CAD</th>
#       <td id="T_692c7_row4_col0" class="data row4 col0" >74745</td>
#       <td id="T_692c7_row4_col1" class="data row4 col1" >74803</td>
#     </tr>
#     <tr>
#       <th id="T_692c7_level0_row5" class="row_heading level0 row5" >CHF</th>
#       <td id="T_692c7_row5_col0" class="data row5 col0" >74951</td>
#       <td id="T_692c7_row5_col1" class="data row5 col1" >74934</td>
#     </tr>
#     <tr>
#       <th id="T_692c7_level0_row6" class="row_heading level0 row6" >CLP</th>
#       <td id="T_692c7_row6_col0" class="data row6 col0" >75057</td>
#       <td id="T_692c7_row6_col1" class="data row6 col1" >75517</td>
#     </tr>
#     <tr>
#       <th id="T_692c7_level0_row7" class="row_heading level0 row7" >CNY</th>
#       <td id="T_692c7_row7_col0" class="data row7 col0" >75112</td>
#       <td id="T_692c7_row7_col1" class="data row7 col1" >74884</td>
#     </tr>
#     <tr>
#       <th id="T_692c7_level0_row8" class="row_heading level0 row8" >COP</th>
#       <td id="T_692c7_row8_col0" class="data row8 col0" >75382</td>
#       <td id="T_692c7_row8_col1" class="data row8 col1" >74859</td>
#     </tr>
#     <tr>
#       <th id="T_692c7_level0_row9" class="row_heading level0 row9" >CZK</th>
#       <td id="T_692c7_row9_col0" class="data row9 col0" >74993</td>
#       <td id="T_692c7_row9_col1" class="data row9 col1" >75527</td>
#     </tr>
#     <tr>
#       <th id="T_692c7_level0_row10" class="row_heading level0 row10" >DKK</th>
#       <td id="T_692c7_row10_col0" class="data row10 col0" >74649</td>
#       <td id="T_692c7_row10_col1" class="data row10 col1" >75595</td>
#     </tr>
#     <tr>
#       <th id="T_692c7_level0_row11" class="row_heading level0 row11" >EGP</th>
#       <td id="T_692c7_row11_col0" class="data row11 col0" >75592</td>
#       <td id="T_692c7_row11_col1" class="data row11 col1" >74933</td>
#     </tr

# %% [markdown]
# __Transaction Authentication Method__

# %%
auth_df = data[["Transaction Authentication Method", 'Fraudulent Flag']]

# Creating a pivot table with currency as index, fraudulent flag as columns and count of fraudulent as values
auth_human_bot = auth_df.pivot_table(values='Fraudulent Flag', index="Transaction Authentication Method", columns='Fraudulent Flag', fill_value=0,
                         aggfunc=lambda x: len(x))

# Passing the pivot table to heatmap for visualization
auth_human_bot.style.background_gradient(cmap ='Blues', axis=0)
# Out:
# <style type="text/css">
# #T_1db3c_row0_col0 {
#   background-color: #84bcdb;
#   color: #000000;
# }
# #T_1db3c_row0_col1 {
#   background-color: #d4e4f4;
#   color: #000000;
# }
# #T_1db3c_row1_col0 {
#   background-color: #1865ac;
#   color: #f1f1f1;
# }
# #T_1db3c_row1_col1 {
#   background-color: #71b1d7;
#   color: #f1f1f1;
# }
# #T_1db3c_row2_col0 {
#   background-color: #4997c9;
#   color: #f1f1f1;
# }
# #T_1db3c_row2_col1 {
#   background-color: #7cb7da;
#   color: #000000;
# }
# #T_1db3c_row3_col0 {
#   background-color: #1e6db2;
#   color: #f1f1f1;
# }
# #T_1db3c_row3_col1 {
#   background-color: #f2f8fd;
#   color: #000000;
# }
# #T_1db3c_row4_col0 {
#   background-color: #56a0ce;
#   color: #f1f1f1;
# }
# #T_1db3c_row4_col1 {
#   background-color: #c1d9ed;
#   color: #000000;
# }
# #T_1db3c_row5_col0, #T_1db3c_row9_col1 {
#   background-color: #dfebf7;
#   color: #000000;
# }
# #T_1db3c_row5_col1 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_1db3c_row6_col0, #T_1db3c_row35_col0 {
#   background-color: #c7dcef;
#   color: #000000;
# }
# #T_1db3c_row6_col1 {
#   background-color: #e6f0f9;
#   color: #000000;
# }
# #T_1db3c_row7_col0 {
#   background-color: #d7e6f5;
#   color: #000000;
# }
# #T_1db3c_row7_col1, #T_1db3c_row34_col0 {
#   background-color: #69add5;
#   color: #f1f1f1;
# }
# #T_1db3c_row8_col0 {
#   background-color: #65aad4;
#   color: #f1f1f1;
# }
# #T_1db3c_row8_col1 {
#   background-color: #6caed6;
#   color: #f1f1f1;
# }
# #T_1db3c_row9_col0 {
#   background-color: #c6dbef;
#   color: #000000;
# }
# #T_1db3c_row10_col0 {
#   background-color: #caddf0;
#   color: #000000;
# }
# #T_1db3c_row10_col1 {
#   background-color: #cfe1f2;
#   color: #000000;
# }
# #T_1db3c_row11_col0, #T_1db3c_row30_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_1db3c_row11_col1, #T_1db3c_row27_col1 {
#   background-color: #5da5d1;
#   color: #f1f1f1;
# }
# #T_1db3c_row12_col0, #T_1db3c_row37_col0 {
#   background-color: #8cc0dd;
#   color: #000000;
# }
# #T_1db3c_row12_col1, #T_1db3c_row30_col0 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_1db3c_row13_col0, #T_1db3c_row38_col0 {
#   background-color: #4e9acb;
#   color: #f1f1f1;
# }
# #T_1db3c_row13_col1 {
#   background-color: #58a1cf;
#   color: #f1f1f1;
# }
# #T_1db3c_row14_col0, #T_1db3c_row35_col1 {
#   background-color: #94c4df;
#   color: #000000;
# }
# #T_1db3c_row14_col1, #T_1db3c_row20_col1 {
#   background-color: #6dafd7;
#   color: #f1f1f1;
# }
# #T_1db3c_row15_col0 {
#   background-color: #91c3de;
#   color: #000000;
# }
# #T_1db3c_row15_col1, #T_1db3c_row19_col0 {
#   background-color: #8fc2de;
#   color: #000000;
# }
# #T_1db3c_row16_col0 {
#   background-color: #ddeaf7;
#   color: #000000;
# }
# #T_1db3c_row16_col1, #T_1db3c_row32_col0 {
#   background-color: #74b3d8;
#   color: #000000;
# }
# #T_1db3c_row17_col0 {
#   background-color: #cadef0;
#   color: #000000;
# }
# #T_1db3c_row17_col1, #T_1db3c_row18_col1, #T_1db3c_row38_col1 {
#   background-color: #87bddc;
#   color: #000000;
# }
# #T_1db3c_row18_col0 {
#   background-color: #6fb0d7;
#   color: #f1f1f1;
# }
# #T_1db3c_row19_col1 {
#   background-color: #ccdff1;
#   color: #000000;
# }
# #T_1db3c_row20_col0 {
#   background-color: #77b5d9;
#   color: #000000;
# }
# #T_1db3c_row21_col0 {
#   background-color: #85bcdc;
#   color: #000000;
# }
# #T_1db3c_row21_col1 {
#   background-color: #d3e4f3;
#   color: #000000;
# }
# #T_1db3c_row22_col0 {
#   background-color: #b0d2e7;
#   color: #000000;
# }
# #T_1db3c_row22_col1 {
#   background-color: #d5e5f4;
#   color: #000000;
# }
# #T_1db3c_row23_col0 {
#   background-color: #3e8ec4;
#   color: #f1f1f1;
# }
# #T_1db3c_row23_col1 {
#   background-color: #afd1e7;
#   color: #000000;
# }
# #T_1db3c_row24_col0, #T_1db3c_row29_col0 {
#   background-color: #99c7e0;
#   color: #000000;
# }
# #T_1db3c_row24_col1 {
#   background-color: #bdd7ec;
#   color: #000000;
# }
# #T_1db3c_row25_col0 {
#   background-color: #3c8cc3;
#   color: #f1f1f1;
# }
# #T_1db3c_row25_col1 {
#   background-color: #b5d4e9;
#   color: #000000;
# }
# #T_1db3c_row26_col0 {
#   background-color: #4695c8;
#   color: #f1f1f1;
# }
# #T_1db3c_row26_col1 {
#   background-color: #d0e2f2;
#   color: #000000;
# }
# #T_1db3c_row27_col0 {
#   background-color: #2676b8;
#   color: #f1f1f1;
# }
# #T_1db3c_row28_col0 {
#   background-color: #66abd4;
#   color: #f1f1f1;
# }
# #T_1db3c_row28_col1 {
#   background-color: #8abfdd;
#   color: #000000;
# }
# #T_1db3c_row29_col1 {
#   background-color: #4594c7;
#   color: #f1f1f1;
# }
# #T_1db3c_row31_col0 {
#   background-color: #1764ab;
#   color: #f1f1f1;
# }
# #T_1db3c_row31_col1 {
#   background-color: #c3daee;
#   color: #000000;
# }
# #T_1db3c_row32_col1 {
#   background-color: #dbe9f6;
#   color: #000000;
# }
# #T_1db3c_row33_col0 {
#   background-color: #d0e1f2;
#   color: #000000;
# }
# #T_1db3c_row33_col1 {
#   background-color: #4b98ca;
#   color: #f1f1f1;
# }
# #T_1db3c_row34_col1 {
#   background-color: #b9d6ea;
#   color: #000000;
# }
# #T_1db3c_row36_col0 {
#   background-color: #f0f6fd;
#   color: #000000;
# }
# #T_1db3c_row36_col1 {
#   background-color: #7ab6d9;
#   color: #000000;
# }
# #T_1db3c_row37_col1 {
#   background-color: #5aa2cf;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_1db3c" class="dataframe">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Fraudulent Flag</th>
#       <th id="T_1db3c_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_1db3c_level0_col1" class="col_heading level0 col1" >1</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Transaction Authentication Method</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1db3c_level0_row0" class="row_heading level0 row0" >Authentication App</th>
#       <td id="T_1db3c_row0_col0" class="data row0 col0" >76922</td>
#       <td id="T_1db3c_row0_col1" class="data row0 col1" >76703</td>
#     </tr>
#     <tr>
#       <th id="T_1db3c_level0_row1" class="row_heading level0 row1" >Behavioral Analytics</th>
#       <td id="T_1db3c_row1_col0" class="data row1 col0" >77349</td>
#       <td id="T_1db3c_row1_col1" class="data row1 col1" >77067</td>
#     </tr>
#     <tr>
#       <th id="T_1db3c_level0_row2" class="row_heading level0 row2" >Behavioral Biometrics</th>
#       <td id="T_1db3c_row2_col0" class="data row2 col0" >77122</td>
#       <td id="T_1db3c_row2_col1" class="data row2 col1" >77035</td>
#     </tr>
#     <tr>
#       <th id="T_1db3c_level0_row3" class="row_heading level0 row3" >Biometric Card</th>
#       <td id="T_1db3c_row3_col0" class="data row3 col0" >77314</td>
#       <td id="T_1db3c_row3_col1" class="data row3 col1" >76526</td>
#     </tr>
#     <tr>
#       <th id="T_1db3c_level0_row4" class="row_heading level0 row4" >Biometric Scan</th>
#       <td id="T_1db3c_row4_col0" class="data row4 col0" >77073</td>
#       <td id="T_1db3c_row4_col1" class="data row4 col1" >76808</td>
#     </tr>
#     <tr>
#       <th id="T_1db3c_level0_row5" class="row_heading level0 row5" >Bluetooth Authentication</th>
#       <td id="T_1db3c_row5_col0" class="data row5 col0" >76547</td>
#       <td id="T_1db3c_row5_col1" class="data row5 col1" >76553</td>
#     </tr>
#     <tr>
#       <th id="T_1db3c_level0_row6" class="row_heading level0 row6" >CAPTCHA</th>
#       <td id="T_1db3c_row6_col0" class="data row6 col0" >76690</td>
#       <td id="T_1db3c_row6_col1" class="data row6 col1" >76599</td>
#     </tr>
#     <tr>
#       <th id="T_1db3c_level0_row7" class="row_heading level0 row7" >Certificate-based Authentication</th>
#       <td id="T_1db3c_row7_col0" class="data row7 col0" >76591</td>
#       <td id="T_1db3c_row7_col1" class="data row7 col1" >77088</td>
#     </tr>
#     <tr>
#       <th id="T_1db3c_level0_row8" class="row_heading level0 row8" >Email Verification</th>
#       <td id="T_1db3c_row8_col0" class="data row8 col0" >77019</td>
#       <td id="T_1db3c_row8_col1" class="data row8 col1" >77081</td>
#     </tr>
#     <tr>
#       <th id="T_1db3c_level0_row9" class="row_heading level0 row9" >Face ID</th>
#       <td id="T_1db3c_row9_col0" class="data row9 col0" >76698</td>
#       <td id="T_1db3c_row9_col1" class="data row9 col1" >76640</td>
#     </tr>
#     <tr>
#       <th id="T_1db3c_level0_row10" class="row_heading level0 row10" >Fingerprint</th>
#       <td id="T_1db3c_row10_col0" class="data row10 col0" >76677</td>
#       <td id="T_1db3c_row10_col1" class="data row10 col1" >76738</td>
#     </tr>
#     <tr>

# %% [markdown]
# Across the different variables visualised, we can see that the number of fraudulent transactions is within the same range with the legit transactions

# %% [markdown]
# __Now, let's see the distribution of the fraudulent transactions and legitimate transactions__

# %% [markdown]
# __LEGITIMATE TRANSACTIONS__

# %%
data.columns
# Out:
# Index(['Transaction ID', 'Transaction Amount', 'Transaction Date and Time',
#        'Merchant ID', 'Payment Method', 'Country Code', 'Transaction Type',
#        'Device Type', 'Browser Type', 'Operating System', 'Merchant Category',
#        'User Age', 'User Occupation', 'User Income', 'User Gender',
#        'User Account Status', 'Transaction Status', 'Location Distance',
#        'Time Taken for Transaction', 'Transaction Time of Day',
#        'User's Transaction History', 'Merchant's Reputation Score',
#        'User's Device Location', 'Transaction Currency', 'Transaction Purpose',
#        'User's Credit Score', 'Merchant's Business Age',
#        'Transaction Authentication Method', 'Fraudulent Flag',
#        'Transaction_ID'],
#       dtype='object')

# %%
# Filter data for legitimate transactions
legits = data[data['Fraudulent Flag'] == 0]
data_grouped_by_trans = legits.groupby(['Transaction_ID'])

features = [('Transaction Amounts', 'Transaction Amount'), ('Payment Methods', 'Payment Method'), ('Country Codes', 'Country Code'),
            ('Transaction Types', 'Transaction Type'), ('Device Types', 'Device Type'), ('Operating Systems', 'Operating System'),
            ('Merchant Categorys', 'Merchant Category'), ('User Ages', 'User Age'), ('User Occupations', 'User Occupation'),
            ('User Incomes', 'User Income'), ('User Genders', 'User Gender'), ('User Account Statuss', 'User Account Status'),
            ('Transaction Statuss', 'Transaction Status'), ('Location Distances', 'Location Distance'),
            ('Time Taken for Transactions', 'Time Taken for Transaction'), ('Transaction Time of Days', 'Transaction Time of Day'),
            ("User's Transaction Historys", "User's Transaction History"), ("Merchant's Reputation Scores", "Merchant's Reputation Score"),
            ("User's Device Locations", "User's Device Location"), ('Transaction Currencys', 'Transaction Currency'),
            ('Transaction Purposes', 'Transaction Purpose'), ("User's Credit Scores", "User's Credit Score"),
            ("Merchant's Business Ages", "Merchant's Business Age"), ('Transaction Authentication Methods', 'Transaction Authentication Method')]

for name, column in features:
    stats = data_grouped_by_trans[column].nunique()

    # Calculate mean, median, mode, min and max for humans
    print("Mean of {} per human: {:.2f}".format(name, stats.mean()))
    print("Median of {} per human: {}".format(name, stats.median()))
    print("Mode of {} per human: {}".format(name, stats.mode()[0]))
    print("Human user with more {}: {}".format(name, stats.max()))
    print("Human user with less {}: {}".format(name, stats.min()))
    print("-----------------------------")
# Out:
# Mean of Transaction Amounts per human: 1.00
# Median of Transaction Amounts per human: 1.0
# Mode of Transaction Amounts per human: 1
# Human user with more Transaction Amounts: 1
# Human user with less Transaction Amounts: 1
# -----------------------------
# Mean of Payment Methods per human: 1.00
# Median of Payment Methods per human: 1.0
# Mode of Payment Methods per human: 1
# Human user with more Payment Methods: 1
# Human user with less Payment Methods: 1
# -----------------------------
# Mean of Country Codes per human: 1.00
# Median of Country Codes per human: 1.0
# Mode of Country Codes per human: 1
# Human user with more Country Codes: 1
# Human user with less Country Codes: 1
# -----------------------------
# Mean of Transaction Types per human: 1.00
# Median of Transaction Types per human: 1.0
# Mode of Transaction Types per human: 1
# Human user with more Transaction Types: 1
# Human user with less Transaction Types: 1
# -----------------------------
# Mean of Device Types per human: 1.00
# Median of Device Types per human: 1.0
# Mode of Device Types per human: 1
# Human user with more Device Types: 1
# Human user with less Device Types: 1
# -----------------------------
# Mean of Operating Systems per human: 1.00
# Median of Operating Systems per human: 1.0
# Mode of Operating Systems per human: 1
# Human user with more Operating Systems: 1
# Human user with less Operating Systems: 1
# -----------------------------
# Mean of Merchant Categorys per human: 1.00
# Median of Merchant Categorys per human: 1.0
# Mode of Merchant Categorys per human: 1
# Human user with more Merchant Categorys: 1
# Human user with less Merchant Categorys: 1
# -----------------------------
# Mean of User Ages per human: 1.00
# Median of User Ages per human: 1.0
# Mode of User Ages per human: 1
# Human user with more User Ages: 1
# Human user with less User Ages: 1
# -----------------------------
# Mean of User Occupations per human: 1.00
# Median of User Occupations per human: 1.0
# Mode of User Occupations per human: 1
# Human user with more User Occupations: 1
# Human user with less User Occupations: 1
# -----------------------------
# Mean of User Incomes per human: 1.00
# Median of User Incomes per human: 1.0
# Mode of User Incomes per human: 1
# Human user with more User Incomes: 1
# Human user with less User Incomes: 1
# -----------------------------
# Mean of User Genders per human: 1.00
# Median of User Genders per human: 1.0
# Mode of User Genders per human: 1
# Human user with more User Genders: 1
# Human user with less User Genders: 1
# -----------------------------
# Mean of User Account Statuss per human: 1.00
# Median of User Account Statuss per human: 1.0
# Mode of User Account Statuss per human: 1
# Human user with more User Account Statuss: 1
# Human user with less User Account Statuss: 1
# -----------------------------
# Mean of Transaction Statuss per human: 1.00
# Median of Transaction Statuss per human: 1.0
# Mode of Transaction Statuss per human: 1
# Human user with more Transaction Statuss: 1
# Human user with less Transaction Statuss: 1
# -----------------------------
# Mean of Location Distances per human: 1.00
# Median of Location Distances per human: 1.0
# Mode of Location Distances per human: 1
# Human user with more Location Distances: 1
# Human user with less Location Distances: 1
# -----------------------------
# Mean of Time Taken for Transactions per human: 1.00
# Median of Time Taken for Transactions per human: 1.0
# Mode of Time Taken for Transactions per human: 1
# Human user with more Time Taken for Transactions: 1
# Human user with less Time Taken for Transactions: 1
# -----------------------------
# Mean of Transaction Time of Days per human: 1.00
# Median of Transaction Time of Days per human: 1.0
# Mode of Transaction Time of Days per human: 1
# Human user with more Transaction Time of Days: 1
# Human user with less Transaction Time of Days: 1
# -----------------------------
# Mean of User's Transaction Historys per human: 1.00
# Median of User's Transaction Historys per human: 1.0
# Mode of User's Transaction Historys per human: 1
# Human user with more User's Transaction Historys: 1
# Human user with less User's Transaction Historys: 1
# -----------------------------
# Mean of Merchant's Reputation Scores per human: 1.00
# Median of Merchant's Reputation Scores per human: 1.0
# Mode of Merchant's Reputation Scores per human: 1
# Human user with more Merchant's Reputation Scores: 1
# Human user with less Merchant's Reputation Scores: 1
# -----------------------------
# Mean of User's Device Locations per human: 1.00
# Median of User's Device Locations per human: 1.0
# Mode of User's Device Locations per human: 1
# Human user with more User's Device Locations: 1
# Human user with less User's Device Locations: 1
# -----------------------------
# Mean of Transaction Currencys per human: 1.00
# Median of Transaction Currencys per human: 1.0
# Mode of Transaction Currencys per human: 1
# Human user with more Transaction Currencys: 1
# Human user with less Transaction Currencys: 1
# -----------------------------
# Mean of Transaction Purposes per human: 1.00
# Median of Transaction Purposes per human: 1.0
# Mode of Transaction Purposes per human: 1
# Human user with more Transaction Purposes: 1
# Human user with less Transaction Purposes: 1
# -----------------------------
# Mean of User's Credit Scores per human: 1.00
# Median of User's Credit Scores per human: 1.0
# Mode of User's Credit Scores per human: 1
# Human user with more User's Credit Scores: 1
# Human user with less User's Credit Scores: 1
# -----------------------------
# Mean of Merchant's Business Ages per human: 1.00
# Median of Merchant's Business Ages per human: 1.0
# Mode of Merchant's Business Ages per human: 1
# Human user with more Merchant's Business Ages: 1
# Human user with less Merchant's Business Ages: 1
# -----------------------------
# Mean of Transaction Authentication Methods per human: 1.00
# Median of Transaction Authentication Methods per human: 1.0
# Mode of Transaction Authentication Methods per human: 1
# Human user with more Transaction Authentication Methods: 1
# Human user with less Transaction Authentication Methods: 1
# -----------------------------

# %% [markdown]
# It is normally distributed. Now, lets see for the fraudulent transactions

# %% [markdown]
# __FRAUDULENT TRANSACTIONS__

# %%
# Filter data for fraudulent transactions
frauds = data[data['Fraudulent Flag'] == 1]
data_grouped_by_trans = frauds.groupby(['Transaction_ID'])

features = [('Transaction Amounts', 'Transaction Amount'), ('Payment Methods', 'Payment Method'), ('Country Codes', 'Country Code'),
            ('Transaction Types', 'Transaction Type'), ('Device Types', 'Device Type'), ('Operating Systems', 'Operating System'),
            ('Merchant Categorys', 'Merchant Category'), ('User Ages', 'User Age'), ('User Occupations', 'User Occupation'),
            ('User Incomes', 'User Income'), ('User Genders', 'User Gender'), ('User Account Statuss', 'User Account Status'),
            ('Transaction Statuss', 'Transaction Status'), ('Location Distances', 'Location Distance'),
            ('Time Taken for Transactions', 'Time Taken for Transaction'), ('Transaction Time of Days', 'Transaction Time of Day'),
            ("User's Transaction Historys", "User's Transaction History"), ("Merchant's Reputation Scores", "Merchant's Reputation Score"),
            ("User's Device Locations", "User's Device Location"), ('Transaction Currencys', 'Transaction Currency'),
            ('Transaction Purposes', 'Transaction Purpose'), ("User's Credit Scores", "User's Credit Score"),
            ("Merchant's Business Ages", "Merchant's Business Age"), ('Transaction Authentication Methods', 'Transaction Authentication Method')]

for name, column in features:
    stats = data_grouped_by_trans[column].nunique()

    # Calculate mean, median, mode, min and max for frauds
    print("Mean of {} per human: {:.2f}".format(name, stats.mean()))
    print("Median of {} per human: {}".format(name, stats.median()))
    print("Mode of {} per human: {}".format(name, stats.mode()[0]))
    print("Human user with more {}: {}".format(name, stats.max()))
    print("Human user with less {}: {}".format(name, stats.min()))
    print("-----------------------------")
# Out:
# Mean of Transaction Amounts per human: 1.00
# Median of Transaction Amounts per human: 1.0
# Mode of Transaction Amounts per human: 1
# Human user with more Transaction Amounts: 1
# Human user with less Transaction Amounts: 1
# -----------------------------
# Mean of Payment Methods per human: 1.00
# Median of Payment Methods per human: 1.0
# Mode of Payment Methods per human: 1
# Human user with more Payment Methods: 1
# Human user with less Payment Methods: 1
# -----------------------------
# Mean of Country Codes per human: 1.00
# Median of Country Codes per human: 1.0
# Mode of Country Codes per human: 1
# Human user with more Country Codes: 1
# Human user with less Country Codes: 1
# -----------------------------
# Mean of Transaction Types per human: 1.00
# Median of Transaction Types per human: 1.0
# Mode of Transaction Types per human: 1
# Human user with more Transaction Types: 1
# Human user with less Transaction Types: 1
# -----------------------------
# Mean of Device Types per human: 1.00
# Median of Device Types per human: 1.0
# Mode of Device Types per human: 1
# Human user with more Device Types: 1
# Human user with less Device Types: 1
# -----------------------------
# Mean of Operating Systems per human: 1.00
# Median of Operating Systems per human: 1.0
# Mode of Operating Systems per human: 1
# Human user with more Operating Systems: 1
# Human user with less Operating Systems: 1
# -----------------------------
# Mean of Merchant Categorys per human: 1.00
# Median of Merchant Categorys per human: 1.0
# Mode of Merchant Categorys per human: 1
# Human user with more Merchant Categorys: 1
# Human user with less Merchant Categorys: 1
# -----------------------------
# Mean of User Ages per human: 1.00
# Median of User Ages per human: 1.0
# Mode of User Ages per human: 1
# Human user with more User Ages: 1
# Human user with less User Ages: 1
# -----------------------------
# Mean of User Occupations per human: 1.00
# Median of User Occupations per human: 1.0
# Mode of User Occupations per human: 1
# Human user with more User Occupations: 1
# Human user with less User Occupations: 1
# -----------------------------
# Mean of User Incomes per human: 1.00
# Median of User Incomes per human: 1.0
# Mode of User Incomes per human: 1
# Human user with more User Incomes: 1
# Human user with less User Incomes: 1
# -----------------------------
# Mean of User Genders per human: 1.00
# Median of User Genders per human: 1.0
# Mode of User Genders per human: 1
# Human user with more User Genders: 1
# Human user with less User Genders: 1
# -----------------------------
# Mean of User Account Statuss per human: 1.00
# Median of User Account Statuss per human: 1.0
# Mode of User Account Statuss per human: 1
# Human user with more User Account Statuss: 1
# Human user with less User Account Statuss: 1
# -----------------------------
# Mean of Transaction Statuss per human: 1.00
# Median of Transaction Statuss per human: 1.0
# Mode of Transaction Statuss per human: 1
# Human user with more Transaction Statuss: 1
# Human user with less Transaction Statuss: 1
# -----------------------------
# Mean of Location Distances per human: 1.00
# Median of Location Distances per human: 1.0
# Mode of Location Distances per human: 1
# Human user with more Location Distances: 1
# Human user with less Location Distances: 1
# -----------------------------
# Mean of Time Taken for Transactions per human: 1.00
# Median of Time Taken for Transactions per human: 1.0
# Mode of Time Taken for Transactions per human: 1
# Human user with more Time Taken for Transactions: 1
# Human user with less Time Taken for Transactions: 1
# -----------------------------
# Mean of Transaction Time of Days per human: 1.00
# Median of Transaction Time of Days per human: 1.0
# Mode of Transaction Time of Days per human: 1
# Human user with more Transaction Time of Days: 1
# Human user with less Transaction Time of Days: 1
# -----------------------------
# Mean of User's Transaction Historys per human: 1.00
# Median of User's Transaction Historys per human: 1.0
# Mode of User's Transaction Historys per human: 1
# Human user with more User's Transaction Historys: 1
# Human user with less User's Transaction Historys: 1
# -----------------------------
# Mean of Merchant's Reputation Scores per human: 1.00
# Median of Merchant's Reputation Scores per human: 1.0
# Mode of Merchant's Reputation Scores per human: 1
# Human user with more Merchant's Reputation Scores: 1
# Human user with less Merchant's Reputation Scores: 1
# -----------------------------
# Mean of User's Device Locations per human: 1.00
# Median of User's Device Locations per human: 1.0
# Mode of User's Device Locations per human: 1
# Human user with more User's Device Locations: 1
# Human user with less User's Device Locations: 1
# -----------------------------
# Mean of Transaction Currencys per human: 1.00
# Median of Transaction Currencys per human: 1.0
# Mode of Transaction Currencys per human: 1
# Human user with more Transaction Currencys: 1
# Human user with less Transaction Currencys: 1
# -----------------------------
# Mean of Transaction Purposes per human: 1.00
# Median of Transaction Purposes per human: 1.0
# Mode of Transaction Purposes per human: 1
# Human user with more Transaction Purposes: 1
# Human user with less Transaction Purposes: 1
# -----------------------------
# Mean of User's Credit Scores per human: 1.00
# Median of User's Credit Scores per human: 1.0
# Mode of User's Credit Scores per human: 1
# Human user with more User's Credit Scores: 1
# Human user with less User's Credit Scores: 1
# -----------------------------
# Mean of Merchant's Business Ages per human: 1.00
# Median of Merchant's Business Ages per human: 1.0
# Mode of Merchant's Business Ages per human: 1
# Human user with more Merchant's Business Ages: 1
# Human user with less Merchant's Business Ages: 1
# -----------------------------
# Mean of Transaction Authentication Methods per human: 1.00
# Median of Transaction Authentication Methods per human: 1.0
# Mode of Transaction Authentication Methods per human: 1
# Human user with more Transaction Authentication Methods: 1
# Human user with less Transaction Authentication Methods: 1
# -----------------------------

# %% [markdown]
# The legitimate transactions are also normally distributed

# %% [markdown]
# ### FEATURE ENGINEERING

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# Now, lets get out the feature and target variable (the independent and dependent variables) and assign them to the input and output variables

# %%
# The important features used for the model was gotten using xgnoost's "feature_importances_". However, the code is displayed below
# as a comment due to insufficient RAM space.

''' import xgboost as xgb
import matplotlib.pyplot as plt


model = xgb.XGBClassifier(
    objective='binary:logistic',
    eval_metric='logloss'
)

#fitting the data into the model
model.fit(x_train, y_train)

# Get feature importance scores
feature_importance = model.feature_importances_

# Get the names of the features
feature_names = list(x_train.columns)

#dictionary for the features
importance_df = pd.DataFrame({'Feature': feature_names, 'Importance': feature_importance})

# Sort the dataframe by importance in descending order
importance_df = importance_df.sort_values(by='Importance', ascending=False)


# Display or visualize the top N important features
top_n = 20
print(f"Top {top_n} Important Features:")
print(importance_df.head(top_n))

# Create a bar plot to visualize feature importance
plt.figure(figsize=(10, 6))
plt.barh(importance_df['Feature'][:top_n], importance_df['Importance'][:top_n])
plt.xlabel('Feature Importance')
plt.ylabel('Feature')
plt.title('Top Feature Importance')
plt.gca().invert_yaxis()
plt.show()
'''
# Out:
# ' import xgboost as xgb\nimport matplotlib.pyplot as plt\n\n\nmodel = xgb.XGBClassifier(\n    objective=\'binary:logistic\',\n    eval_metric=\'logloss\'\n)\n\n#fitting the data into the model\nmodel.fit(x_train, y_train)\n\n# Get feature importance scores\nfeature_importance = model.feature_importances_\n\n# Get the names of the features\nfeature_names = list(x_train.columns)\n\n#dictionary for the features\nimportance_df = pd.DataFrame({\'Feature\': feature_names, \'Importance\': feature_importance})\n\n# Sort the dataframe by importance in descending order\nimportance_df = importance_df.sort_values(by=\'Importance\', ascending=False)\n\n\n# Display or visualize the top N important features\ntop_n = 20\nprint(f"Top {top_n} Important Features:")\nprint(importance_df.head(top_n))\n\n# Create a bar plot to visualize feature importance\nplt.figure(figsize=(10, 6))\nplt.barh(importance_df[\'Feature\'][:top_n], importance_df[\'Importance\'][:top_n])\nplt.xlabel(\'Feature Importance\')\nplt.ylabel(\'Feature\')\nplt.title(\'Top Feature Importance\')\nplt.gca().invert_yaxis()\nplt.show()\n'

# %%
independent = ['Transaction Amount', 'Merchant ID', 'Payment Method', 'Country Code',
       'Device Type', 'Browser Type',
       'User Age', 'User Occupation', 'User Gender',
       'Transaction Status', 'Location Distance',
       'Time Taken for Transaction',
       "Merchant's Reputation Score",
       "User's Device Location", 'Transaction Currency', 'Transaction Purpose',
       "User's Credit Score",
       'Transaction Authentication Method']

# %%
dependent = [ 'Fraudulent Flag']

# %%
x = data[independent]

y = data[dependent]

# %% [markdown]
# It's now time for encoding

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder

# %%
from sklearn.preprocessing import LabelEncoder, OneHotEncoder

# Initialize label encoder and one-hot encoder
label_encoder = LabelEncoder()
one_hot_encoder = OneHotEncoder(sparse=False, drop='first')

# Create a DataFrame to store encoded data
encoded_data = x.copy()

# Iterate over categorical columns and apply encoding
for col in independent:
    if x[col].dtype == 'object':  # Check if the column is categorical
        if len(x[col].unique()) <= 50:
            encoded_data[col] = label_encoder.fit_transform(x[col])
        else:
            # Use a temporary DataFrame to perform one-hot encoding
            one_hot_encoded = one_hot_encoder.fit_transform(x[[col]])
            col_names = one_hot_encoder.get_feature_names_out([col])

            # Assign the one-hot encoded values to the corresponding columns in the main DataFrame
            encoded_data[col_names] = one_hot_encoded

            # Drop the original categorical column from the main DataFrame
            encoded_data.drop(col, axis=1, inplace=True)

# You may want to reset the index if needed
# encoded_data.reset_index(drop=True, inplace=True)

# %%
#reassign the encoded data back to the x variable
x = encoded_data

# %%
x.head()
# Out:
#    Transaction Amount  Merchant ID  Payment Method  Country Code  Device Type  \
# 0              163.08         4044               1            19           10
# 1              430.74         4576               0            38           18
# 2              415.74         4629              20            21           34
# 3              565.89         3322              10            30           16
# 4              955.49         7609              39            13           27
#
#    Browser Type  User Age  User Occupation  User Gender  Transaction Status  \
# 0            15        68                7            6                  19
# 1             2        22                5            2                  32
# 2            21        71               16            3                  26
# 3            14        78               16            0                   6
# 4             1        31               17            3                  30
#
#    Location Distance  Time Taken for Transaction  Merchant's Reputation Score  \
# 0               9.34                       24.22                         2.71
# 1              65.28                       55.11                         3.95
# 2              44.05                       53.84                         3.81
# 3              21.70                       21.62                         2.67
# 4              56.63                       53.71                         3.19
#
#    User's Device Location  Transaction Currency  Transaction Purpose  \
# 0                      37                    24                    9
# 1                      18                    11                    6
# 2                      24                    22                    0
# 3                      30                     6                   20
# 4                      14                    31                   11
#
#    User's Credit Score  Transaction Authentication Method
# 0                  343                                  5
# 1                  688                                 18
# 2                  371                                 33
# 3                  687                                 32
# 4                  605                                 21

# %% [markdown]
# ### SPLIT THE DATASET TO TEST AND TRAIN

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.1, random_state=42)

# %% [markdown]
# __FEATURE SCALING__

# %%
#columns for the feature scaling
feat_sca = ['Transaction Amount', 'Merchant ID', 'User Age', 'Time Taken for Transaction', 'Location Distance',
             "Merchant's Reputation Score", "Transaction Authentication Method"]

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x_train[feat_sca] = sc.fit_transform(x_train[feat_sca])
x_test[feat_sca] = sc.transform(x_test[feat_sca])

# %% [markdown]
# ### HYPERTUNUNG THE MODEL

# %%
x_train.dropna(inplace=True)
y_train.dropna(inplace=True)
x_test.dropna(inplace=True)
y_test.dropna(inplace=True)

# %% [markdown]
# ### BUILDING THE MODEL

# %% [markdown]
# ### XGBOOST

# %%
import xgboost as xgb
from sklearn.metrics import accuracy_score

# %%
model = xgb.XGBClassifier(
    objective='binary:logistic',
    eval_metric='logloss'  )

max_depth = 6
learning_rate = 0.1
n_estimators = 100


model = xgb.XGBClassifier(
    objective='binary:logistic',
    eval_metric='logloss',
    max_depth=max_depth,
    learning_rate=learning_rate,
    n_estimators=n_estimators,
    n_jobs=-1
)

# %%
model.fit(x_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric='logloss',
#               feature_types=None, gamma=None, gpu_id=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=0.1, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=6,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, n_estimators=100, n_jobs=-1,
#               num_parallel_tree=None, predictor=None, random_state=None, ...)

# %%
y_pred = model.predict(x_test)

# %%
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy:.2f}")
# Out:
# Accuracy: 0.50
